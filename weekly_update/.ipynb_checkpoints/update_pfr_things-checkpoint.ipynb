# %%
import read_pfr as rp
import json
import os
import pandas as pd

# %%
dictionary = rp.read_season_sched(2016)
dictionary
# Out:
# Reading https://pro-football-reference.com/years/2016/games.htm

# %%
# One-time run to get game history
import read_pfr as rp
import json
import os

datapath = "/home/welced12/googledrive/nfl_data/devl/pfr_gamedata.json"

# Load existing games from json file
games_dict = {}
if os.path.isfile( datapath ):
    with open(datapath, 'r') as f:
        games_dict = json.load(f)
        
# Get raw pages from 1975 to 2017
for year in range(1975,2019):
    season_dict = rp.read_season_sched( year )
    print(season_dict.keys())
    games_dict[year] = season_dict

with open(datapath, 'w') as f:
    json.dump(games_dict, f)
# Out:
# Reading https://pro-football-reference.com/years/1975/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1976/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1977/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1978/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1979/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1980/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1981/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1982/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1983/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1984/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1985/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1986/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1987/games.htm
# dict_keys(['games_clone', 'games'])
# Reading https://pro-football-reference.com/years/1988/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1989/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1990/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1991/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1992/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1993/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1994/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1995/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1996/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1997/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1998/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/1999/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2000/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2001/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2002/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2003/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2004/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2005/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2006/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2007/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2008/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2009/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2010/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2011/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2012/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2013/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2014/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2015/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2016/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2017/games.htm
# dict_keys(['games'])
# Reading https://pro-football-reference.com/years/2018/games.htm
# dict_keys(['games'])

# %%
pd.DataFrame(games_dict[2016]['games'])
# Out:
#     boxscore_word boxscore_word_a           boxscore_word_href     game_date  \
# 0             NaN        boxscore  /boxscores/201609080den.htm   September 8
# 1             NaN        boxscore  /boxscores/201609110rav.htm  September 11
# 2             NaN        boxscore  /boxscores/201609110jax.htm  September 11
# 3             NaN        boxscore  /boxscores/201609110nyj.htm  September 11
# 4             NaN        boxscore  /boxscores/201609110phi.htm  September 11
# 5             NaN        boxscore  /boxscores/201609110htx.htm  September 11
# 6             NaN        boxscore  /boxscores/201609110kan.htm  September 11
# 7             NaN        boxscore  /boxscores/201609110atl.htm  September 11
# 8             NaN        boxscore  /boxscores/201609110oti.htm  September 11
# 9             NaN        boxscore  /boxscores/201609110nor.htm  September 11
# 10            NaN        boxscore  /boxscores/201609110sea.htm  September 11
# 11            NaN        boxscore  /boxscores/201609110dal.htm  September 11
# 12            NaN        boxscore  /boxscores/201609110clt.htm  September 11
# 13            NaN        boxscore  /boxscores/201609110crd.htm  September 11
# 14            NaN        boxscore  /boxscores/201609120was.htm  September 12
# 15            NaN        boxscore  /boxscores/201609120sfo.htm  September 12
# 16                            NaN                          NaN          Date
# 17            NaN        boxscore  /boxscores/201609150buf.htm  September 15
# 18            NaN        boxscore  /boxscores/201609180det.htm  September 18
# 19            NaN        boxscore  /boxscores/201609180pit.htm  September 18
# 20            NaN        boxscore  /boxscores/201609180cle.htm  September 18
# 21            NaN        boxscore  /boxscores/201609180htx.htm  September 18
# 22            NaN        boxscore  /boxscores/201609180nwe.htm  September 18
# 23            NaN        boxscore  /boxscores/201609180was.htm  September 18
# 24            NaN        boxscore  /boxscores/201609180nyg.htm  September 18
# 25            NaN        boxscore  /boxscores/201609180car.htm  September 18
# 26            NaN        boxscore  /boxscores/201609180crd.htm  September 18
# 27            NaN        boxscore  /boxscores/201609180ram.htm  September 18
# 28            NaN        boxscore  /boxscores/201609180rai.htm  September 18
# 29            NaN        boxscore  /boxscores/201609180den.htm  September 18
# ..            ...             ...                          ...           ...
# 254           NaN        boxscore  /boxscores/201612260dal.htm   December 26
# 255                           NaN                          NaN          Date
# 256           NaN        boxscore  /boxscores/201701010phi.htm     January 1
# 257           NaN        boxscore  /boxscores/201701010tam.htm     January 1
# 258           NaN        boxscore  /boxscores/201701010mia.htm     January 1
# 259           NaN        boxscore  /boxscores/201701010nyj.htm     January 1
# 260           NaN        boxscore  /boxscores/201701010pit.htm     January 1
# 261           NaN        boxscore  /boxscores/201701010min.htm     January 1
# 262           NaN        boxscore  /boxscores/201701010oti.htm     January 1
# 263           NaN        boxscore  /boxscores/201701010clt.htm     January 1
# 264           NaN        boxscore  /boxscores/201701010cin.htm     January 1
# 265           NaN        boxscore  /boxscores/201701010was.htm     January 1
# 266           NaN        boxscore  /boxscores/201701010sfo.htm     January 1
# 267           NaN        boxscore  /boxscores/201701010ram.htm     January 1
# 268           NaN        boxscore  /boxscores/201701010den.htm     January 1
# 269           NaN        boxscore  /boxscores/201701010sdg.htm     January 1
# 270           NaN        boxscore  /boxscores/201701010atl.htm     January 1
# 271           NaN        boxscore  /boxscores/201701010det.htm     January 1
# 272                           NaN                          NaN
# 273           NaN        boxscore  /boxscores/201701070htx.htm     January 7
# 274           NaN        boxscore  /boxscores/201701070sea.htm     January 7
# 275           NaN        boxscore  /boxscores/201701080pit.htm     January 8
# 276           NaN        boxscore  /boxscores/201701080gnb.htm     January 8
# 277           NaN        boxscore  /boxscores/201701140atl.htm    January 14
# 278           NaN        boxscore  /boxscores/201701140nwe.htm    January 14
# 279           NaN        boxscore  /boxscores/201701150dal.htm    January 15
# 280           NaN        boxscore  /boxscores/201701150kan.htm    January 15
# 281           NaN        boxscore  /boxscores/201701220atl.htm    January 22
# 282           NaN        boxscore  /boxscores/201701220nwe.htm    January 22
# 283           NaN        boxscore  /boxscores/201702050atl.htm    February 5
#
#     game_day_of_week game_location gametime      loser               loser_a  \
# 0                Thu                 8:40PM        NaN     Carolina Panthers
# 1                Sun                 1:04PM        NaN         Buffalo Bills
# 2                Sun             @   1:04PM        NaN  Jacksonville Jaguars
# 3                Sun             @   1:05PM        NaN         New York Jets
# 4                Sun                 1:05PM        NaN      Cleveland Browns
# 5                Sun                 1:05PM        NaN         Chicago Bears
# 6                Sun                 1:05PM        NaN    San Diego Chargers
# 7                Sun             @   1:05PM        NaN       Atlanta Falcons
# 8                Sun             @   1:05PM        NaN      Tennessee Titans
# 9                Sun             @   1:05PM        NaN    New Orleans Saints
# 10               Sun                 4:08PM        NaN        Miami Dolphins
# 11               Sun             @   4:27PM        NaN        Dallas Cowboys
# 12               Sun             @   4:27PM        NaN    Indianapolis Colts
# 13               Sun             @   8:30PM        NaN     Arizona Cardinals
# 14               Mon             @   7:11PM        NaN   Washington Redskins
# 15               Mon                10:20PM        NaN      Los Angeles Rams
# 16               Day                   Time  Loser/tie                   NaN
# 17               Thu             @   8:26PM        NaN         Buffalo Bills
# 18               Sun             @   1:02PM        NaN         Detroit Lions
# 19               Sun                 1:02PM        NaN    Cincinnati Bengals
# 20               Sun             @   1:02PM        NaN      Cleveland Browns
# 21               Sun                 1:02PM        NaN    Kansas City Chiefs
# 22               Sun                 1:02PM        NaN        Miami Dolphins
# 23               Sun             @   1:03PM        NaN   Washington Redskins
# 24               Sun                 1:03PM        NaN    New Orleans Saints
# 25               Sun                 1:03PM        NaN   San Francisco 49ers
# 26               Sun                 1:05PM        NaN  Tampa Bay Buccaneers
# 27               Sun                 4:08PM        NaN      Seattle Seahawks
# 28               Sun             @   4:25PM        NaN       Oakland Raiders
# 29               Sun                 4:25PM        NaN    Indianapolis Colts
# ..               ...           ...      ...        ...                   ...
# 254              Mon                 8:30PM        NaN         Detroit Lions
# 255              Day                   Time  Loser/tie                   NaN
# 256              Sun                 1:00PM        NaN        Dallas Cowboys
# 257              Sun                 1:00PM        NaN     Carolina Panthers
# 258              Sun             @   1:00PM        NaN        Miami Dolphins
# 259              Sun                 1:00PM        NaN         Buffalo Bills
# 260              Sun                 1:00PM        NaN      Cleveland Browns
# 261              Sun                 1:00PM        NaN         Chicago Bears
# 262              Sun                 1:00PM        NaN        Houston Texans
# 263              Sun                 1:00PM        NaN  Jacksonville Jaguars
# 264              Sun                 1:00PM        NaN      Baltimore Ravens
# 265              Sun             @   4:25PM        NaN   Washington Redskins
# 266              Sun             @   4:25PM        NaN   San Francisco 49ers
# 267              Sun             @   4:25PM        NaN      Los Angeles Rams
# 268              Sun                 4:25PM        NaN       Oakland Raiders
# 269              Sun             @   4:25PM        NaN    San Diego Chargers
# 270              Sun                 4:25PM        NaN    New Orleans Saints
# 271              Sun             @   8:30PM        NaN         Detroit Lions
# 272                                                                      NaN
# 273              Sat                 4:35PM        NaN       Oakland Raiders
# 274              Sat                 8:15PM        NaN         Detroit Lions
# 275              Sun                 1:05PM        NaN        Miami Dolphins
# 276              Sun                 4:40PM        NaN       New York Giants
# 277              Sat                 4:35PM        NaN      Seattle Seahawks
# 278              Sat                 8:15PM        NaN        Houston Texans
# 279              Sun             @   4:40PM        NaN        Dallas Cowboys
# 280              Sun             @   8:20PM        NaN    Kansas City Chiefs
# 281              Sun                 3:05PM        NaN     Green Bay Packers
# 282              Sun                 6:40PM        NaN   Pittsburgh Steelers
# 283              Sun             N   6:30PM        NaN       Atlanta Falcons
#
#               loser_href    ...    pts_win rowclass to_lose to_win   week_num  \
# 0    /teams/car/2016.htm    ...                 NaN       1      3          1
# 1    /teams/buf/2016.htm    ...                 NaN       0      1          1
# 2    /teams/jax/2016.htm    ...                 NaN       1      0          1
# 3    /teams/nyj/2016.htm    ...                 NaN       1      1          1
# 4    /teams/cle/2016.htm    ...                 NaN       1      0          1
# 5    /teams/chi/2016.htm    ...                 NaN       1      1          1
# 6    /teams/sdg/2016.htm    ...                 NaN       0      1          1
# 7    /teams/atl/2016.htm    ...                 NaN       0      1          1
# 8    /teams/oti/2016.htm    ...                 NaN       3      0          1
# 9    /teams/nor/2016.htm    ...                 NaN       1      0          1
# 10   /teams/mia/2016.htm    ...                 NaN       0      2          1
# 11   /teams/dal/2016.htm    ...                 NaN       0      1          1
# 12   /teams/clt/2016.htm    ...                 NaN       0      0          1
# 13   /teams/crd/2016.htm    ...                 NaN       0      2          1
# 14   /teams/was/2016.htm    ...                 NaN       2      1          1
# 15   /teams/ram/2016.htm    ...                 NaN       2      1          1
# 16                   NaN    ...        Pts    thead     TOL    TOW       Week
# 17   /teams/buf/2016.htm    ...                 NaN       1      1          2
# 18   /teams/det/2016.htm    ...                 NaN       1      1          2
# 19   /teams/cin/2016.htm    ...                 NaN       2      2          2
# 20   /teams/cle/2016.htm    ...                 NaN       2      2          2
# 21   /teams/kan/2016.htm    ...                 NaN       3      2          2
# 22   /teams/mia/2016.htm    ...                 NaN       4      1          2
# 23   /teams/was/2016.htm    ...                 NaN       1      1          2
# 24   /teams/nor/2016.htm    ...                 NaN       0      3          2
# 25   /teams/sfo/2016.htm    ...                 NaN       3      4          2
# 26   /teams/tam/2016.htm    ...                 NaN       5      0          2
# 27   /teams/sea/2016.htm    ...                 NaN       1      0          2
# 28   /teams/rai/2016.htm    ...                 NaN       0      1          2
# 29   /teams/clt/2016.htm    ...                 NaN       2      1          2
# ..                   ...    ...        ...      ...     ...    ...        ...
# 254  /teams/det/2016.htm    ...                 NaN       2      0         16
# 255                  NaN    ...        Pts    thead     TOL    TOW       Week
# 256  /teams/dal/2016.htm    ...                 NaN       2      0         17
# 257  /teams/car/2016.htm    ...                 NaN       3      2         17
# 258  /teams/mia/2016.htm    ...                 NaN       2      0         17
# 259  /teams/buf/2016.htm    ...                 NaN       3      0         17
# 260  /teams/cle/2016.htm    ...                 NaN       4      1         17
# 261  /teams/chi/2016.htm    ...                 NaN       5      1         17
# 262  /teams/htx/2016.htm    ...                 NaN       1      1         17
# 263  /teams/jax/2016.htm    ...                 NaN       2      2         17
# 264  /teams/rav/2016.htm    ...                 NaN       2      0         17
# 265  /teams/was/2016.htm    ...                 NaN       3      0         17
# 266  /teams/sfo/2016.htm    ...                 NaN       2      0         17
# 267  /teams/ram/2016.htm    ...                 NaN       3      2         17
# 268  /teams/rai/2016.htm    ...                 NaN       3      1         17
# 269  /teams/sdg/2016.htm    ...                 NaN       2      1         17
# 270  /teams/nor/2016.htm    ...                 NaN       1      0         17
# 271  /teams/det/2016.htm    ...                 NaN       1      0         17
# 272                  NaN    ...                 NaN
# 273  /teams/rai/2016.htm    ...                 NaN       3      0   WildCard
# 274  /teams/det/2016.htm    ...                 NaN       0      0   WildCard
# 275  /teams/mia/2016.htm    ...                 NaN       3      2   WildCard
# 276  /teams/nyg/2016.htm    ...                 NaN       2      0   WildCard
# 277  /teams/sea/2016.htm    ...                 NaN       2      0   Division
# 278  /teams/htx/2016.htm    ...                 NaN       3      3   Division
# 279  /teams/dal/2016.htm    ...                 NaN       1      1   Division
# 280  /teams/kan/2016.htm    ...                 NaN       2      1   Division
# 281  /teams/gnb/2016.htm    ...                 NaN       2      0  ConfChamp
# 282  /teams/pit/2016.htm    ...                 NaN       2      0  ConfChamp
# 283  /teams/atl/2016.htm    ...                 NaN       1      2  SuperBowl
#
#          winner winner_a winner_href yards_lose yards_win
# 0                    NaN         NaN        333       307
# 1                    NaN         NaN        160       308
# 2                    NaN         NaN        348       294
# 3                    NaN         NaN        340       381
# 4                    NaN         NaN        288       403
# 5                    NaN         NaN        258       344
# 6                    NaN         NaN        388       413
# 7                    NaN         NaN        374       371
# 8                    NaN         NaN        316       301
# 9                    NaN         NaN        507       486
# 10                   NaN         NaN        214       352
# 11                   NaN         NaN        328       316
# 12                   NaN         NaN        450       448
# 13                   NaN         NaN        344       363
# 14                   NaN         NaN        384       437
# 15                   NaN         NaN        185       320
# 16   Winner/tie      NaN         NaN       YdsL      YdsW
# 17                   NaN         NaN        393       493
# 18                   NaN         NaN        375       363
# 19                   NaN         NaN        412       374
# 20                   NaN         NaN        387       382
# 21                   NaN         NaN        291       351
# 22                   NaN         NaN        457       463
# 23                   NaN         NaN        432       380
# 24                   NaN         NaN        288       417
# 25                   NaN         NaN        302       529
# 26                   NaN         NaN        306       416
# 27                   NaN         NaN        306       283
# 28                   NaN         NaN        454       528
# 29                   NaN         NaN        253       400
# ..          ...      ...         ...        ...       ...
# 254                  NaN         NaN        319       375
# 255  Winner/tie      NaN         NaN       YdsL      YdsW
# 256                  NaN         NaN        195       346
# 257                  NaN         NaN        335       300
# 258                  NaN         NaN        280       396
# 259                  NaN         NaN        230       329
# 260                  NaN         NaN        437       312
# 261                  NaN         NaN        323       374
# 262                  NaN         NaN        289       236
# 263                  NaN         NaN        470       384
# 264                  NaN         NaN        335       371
# 265                  NaN         NaN        284       332
# 266                  NaN         NaN        253       376
# 267                  NaN         NaN        123       344
# 268                  NaN         NaN        221       349
# 269                  NaN         NaN        398       365
# 270                  NaN         NaN        473       465
# 271                  NaN         NaN        408       448
# 272                  NaN         NaN
# 273                  NaN         NaN        203       291
# 274                  NaN         NaN        231       387
# 275                  NaN         NaN        305       367
# 276                  NaN         NaN        365       406
# 277                  NaN         NaN        309       422
# 278                  NaN         NaN        285       377
# 279                  NaN         NaN        429       413
# 280                  NaN         NaN        227       389
# 281                  NaN         NaN        367       493
# 282                  NaN         NaN        368       431
# 283                  NaN         NaN        344       546
#
# [284 rows x 21 columns]

# %%
# Script for updating a particular season's game data and update gameids
def update_season_page( year ):
    import read_pfr as rp
    import json
    import os

    datapath = "/home/welced12/googledrive/nfl_data/devl/pfr_gamedata.json"
    
    # Read season schedule page for specified season
    season_dict = rp.read_season_sched( year )
    print("passed the read_season_sched function")
    print(season_dict.keys())
    
    if ('games' in season_dict.keys()) or ('all_games' in season_dict.keys()):
        
        # Load existing games from json file
        games_dict = {}
        if os.path.isfile( datapath ):
            with open(datapath, 'r') as f:
                games_dict = json.load(f)
                
        print("Loaded existing games")
        print(games_dict.keys())
                
        # Update value for this particular season with new table
        games_dict[str(year)] = season_dict
        print("Added specific season to existing games")
        print(games_dict.keys())
        
        # Write resulting overall dictionary to file
        with open(datapath, 'w') as f:
            json.dump(games_dict, f)
            
    else:
        print("Page for"+str(year)+"doesn't have a 'games' table")

# %%
update_season_page( 2018 )
# Out:
# Reading https://pro-football-reference.com/years/2018/games.htm
# passed the read_season_sched function
# dict_keys(['games'])
# Loaded existing games
# dict_keys(['2016', '2017', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2018'])
# Added specific season to existing games
# dict_keys(['2016', '2017', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2018', 2018])

# %%
games_dict.keys()
# Out:
# dict_keys(['2016', '2017', 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])

# %%
games_dict.keys()
# Out:
# dict_keys(['2016', '2017', 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])

# %% [markdown]
# # New below here

# %%
# read_pfr.py module

import pandas as pd
import numpy as np
from selenium import webdriver
from lxml import etree
import time
import json
import os

def read_table( html_tree, 
                tablename ):
    
    # Make list to house dictionaries for each row
    rows = []
    tablepath = '//table[@id="{0}"]/tbody/tr'.format(tablename)
    
    # Split table into rows
    for row in html_tree.xpath(tablepath):
        
        # Make a dictionary to store each cell in the row
        rd = {}
        rowclass = row.xpath('./@class')
        try:
            rd["rowclass"] = rowclass[0]
        except:
            pass
        try:
            cells = [e for e in row.xpath('./td|./th')]
            for i, cell in enumerate(cells):
                
                # Depending on cell contents, add cell to row dict
                try:
                    txt = cell.xpath('./text()')
                    a_text = cell.xpath('./a/text()')
                    a_href = cell.xpath('./a/@href')
                    stat = cell.xpath('./@data-stat')
                
                    # Logic map for cell contents
                    if (len(txt) >= 1) and (len(a_text) >= 1):
                        # Have both links and standard text. Save both
                        rd[stat[0]+"_text"] = "brk, ".join(txt)
                        rd[stat[0]+"_a"] = ", ".join(a_text)
                        rd[stat[0]+"_href"] = ", ".join(a_href)
                    elif len(a_text) >= 1:
                        # Have just text from a link
                        rd[stat[0]+"_a"] = a_text[0]
                        rd[stat[0]+"_href"] = a_href[0]
                    else:
                        try:
                            # Maybe we just have text
                            rd[stat[0]] = txt[0]
                        except:
                            # If all fails, then we probably have no text
                            rd[stat[0]] = ""
                                        
                except:
                    print("Couldn't parse cell")
            
            
            # Add row dictionary to list of rows
            rows.append(rd)

        except:
            pass
        
    return rows


# One function to take an element tree and parse all of the tables on it
def get_tables(url):
    
    options = webdriver.ChromeOptions()
    options.add_argument('headless')

    driver = webdriver.Chrome(chrome_options=options)
    try:
        driver.get(url)
        page_html = driver.page_source
        tree = etree.HTML(page_html)
        tablenames = tree.xpath('//table/@id')
        
    except:
        print("webdriver failed to get url",url)
        tablenames = [""]
    driver.quit()
    
    tables = {}
    for tab in tablenames:
        try:
            tables[tab] = read_table(tree, tab)
        except:
            print("Failed to read table",tab)
            tables[tab] = ""
            
    return tables


def read_season_sched( season ):
    url = "https://pro-football-reference.com/years/"+str(season)+"/games.htm"
    print("Reading",url)
    season_dict = {"":""}
    tries = 1
    while (tries < 5) and ( season_dict == {"":""} ):
        season_dict = get_tables(url)
        tries += 1
        time.sleep(0.1) 
    return season_dict


def read_game_page( gid ):
    url = "https://pro-football-reference.com"+str(gid)
    print("Trying to read",url)
    game_dict = {"":""}
    tries = 1
    while (tries < 5) and ( game_dict == {"":""} ):
        game_dict = get_tables(url)
        tries += 1
        time.sleep(0.1)
    return game_dict

# %%
# Organizational structure
### Results files locations
filesdir = '/home/welced12/googledrive/nfl_data/devl/'
gamesinfo = filesdir+'pfr_gamedata.json'

### Collect pages for individual games in separate file for each game
### Can use those to create dataset for plays or individual stats

# %%
# One-time use to build game history

#datapath = "/home/welced12/googledrive/nfl_data/devl/pfr_gamedata.json"
datapath = '/home/welced12/git/football_analytics/pfr_pages'

# Load existing games from json file
games_dict = {}
if os.path.isfile( datapath ):
    with open(datapath, 'r') as f:
        games_dict = json.load(f)
        
# Get raw pages from 1975 to 2018
for year in range(1975,2019):
    season_dict = read_season_sched( year )
    print(season_dict.keys())
    games_dict[str(year)] = season_dict

with open(datapath, 'w') as f:
    json.dump(games_dict, f)
# Out:
# Reading https://pro-football-reference.com/years/1975/games.htm
# webdriver failed to get url https://pro-football-reference.com/years/1975/games.htm
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-83-5e89b30e9309> in <module>()
#      12 # Get raw pages from 1975 to 2018
#      13 for year in range(1975,2019):
# ---> 14     season_dict = read_season_sched( year )
#      15     print(season_dict.keys())
#      16     games_dict[str(year)] = season_dict
#
# <ipython-input-26-c1a0a3726279> in read_season_sched(season)
#     103     tries = 1
#     104     while (tries < 5) and ( season_dict == {"":""} ):
# --> 105         season_dict = get_tables(url)
#     106         tries += 1
#     107         time.sleep(0.1)
#
# <ipython-input-26-c1a0a3726279> in get_tables(url)
#      84         print("webdriver failed to get url",url)
#      85         tablenames = [""]
# ---> 86     driver.quit()
#      87
#      88     tables = {}
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chrome/webdriver.py in quit(self)
#     127             pass
#     128         finally:
# --> 129             self.service.stop()
#     130
#     131     def create_options(self):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/common/service.py in stop(self)
#     149
#     150         try:
# --> 151             self.send_remote_shutdown_command()
#     152         except TypeError:
#     153             pass
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/common/service.py in send_remote_shutdown_command(self)
#     125
#     126         try:
# --> 127             url_request.urlopen("%s/shutdown" % self.service_url)
#     128         except URLError:
#     129             return
#
# ~/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# ~/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ConnectionResetError: [Errno 104] Connection reset by peer

# %%
# Script for updating a particular season's game data and update gameids
def update_season_page( year ):
#    import read_pfr as rp
    import json
    import os

    datapath = "/home/welced12/googledrive/nfl_data/devl/pfr_gamedata.json"
    
    # Read season schedule page for specified season
    season_dict = read_season_sched( year )
    
    if ('games' in season_dict.keys()) or ('all_games' in season_dict.keys()):
        
        # Load existing games from json file
        games_dict = {}
        if os.path.isfile( datapath ):
            with open(datapath, 'r') as f:
                games_dict = json.load(f)                
            print("Loaded existing games")
                
        # Update value for this particular season with new table
        games_dict[str(year)] = season_dict
        print("Updated game data from",year)
        print("Writing game data to",datapath)
        
        # Write resulting overall dictionary to file
        with open(datapath, 'w') as f:
            json.dump(games_dict, f)
            
    else:
        print("Page for"+str(year)+"doesn't have a 'games' table")

# %%
update_season_page( 2018 )
# Out:
# Reading https://pro-football-reference.com/years/2018/games.htm
# Loaded existing games
# Updated game data from 2018

# %%
# Get pages for games for a particular week
def pfr_read_week(season, week):
    yr = str(season)
    wk = str(week)
    
    # Load game history from file
    gamelistpath = '/home/welced12/googledrive/nfl_data/devl/pfr_gamedata.json'
    with open(gamelistpath, 'r') as f:
        games_dict = json.load(f)
    # Make DataFrame of games for specified season
    if yr in games_dict.keys():
        if ('games' in games_dict[yr].keys()):
            season_df = pd.DataFrame(games_dict[yr]['games'])
        elif ('all_games' in games_dict[yr].keys()):
            season_df = pd.DataFrame(games_dict[yr]['all_games'])
            
        week_df = season_df[season_df.week_num == wk]
        gameids = week_df.boxscore_word_href.values
        gameurls = ['https://www.pro-football-reference.com'+gid for gid in gameids]
        
        # Scrape boxscore page for each of the gameids.
        for gid in gameids:
            
            game_dict = read_game_page( gid )
            
            # Store the resulting dictionary of tables as a json
            basedir = '/home/welced12/googledrive/nfl_data/devl'
            gamefile = basedir+gid.split('.')[0]+".json"
            with open(gamefile, 'w') as f:
                print(" ^ Saving tables to",gamefile)
                json.dump(game_dict, f)
        
    else:
        print("No games on file for",yr)
    
pfr_read_week(2018,2)
# Out:
# Trying to read https://pro-football-reference.com/boxscores/201809130cin.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809130cin.json
# Trying to read https://pro-football-reference.com/boxscores/201809160tam.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160tam.json
# Trying to read https://pro-football-reference.com/boxscores/201809160buf.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160buf.json
# Trying to read https://pro-football-reference.com/boxscores/201809160oti.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160oti.json
# Trying to read https://pro-football-reference.com/boxscores/201809160nyj.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160nyj.json
# Trying to read https://pro-football-reference.com/boxscores/201809160nor.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160nor.json
# Trying to read https://pro-football-reference.com/boxscores/201809160gnb.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160gnb.json
# Trying to read https://pro-football-reference.com/boxscores/201809160pit.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160pit.json
# Trying to read https://pro-football-reference.com/boxscores/201809160was.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160was.json
# Trying to read https://pro-football-reference.com/boxscores/201809160atl.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160atl.json
# Trying to read https://pro-football-reference.com/boxscores/201809160sfo.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160sfo.json
# Trying to read https://pro-football-reference.com/boxscores/201809160ram.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160ram.json
# Trying to read https://pro-football-reference.com/boxscores/201809160jax.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160jax.json
# Trying to read https://pro-football-reference.com/boxscores/201809160den.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160den.json
# Trying to read https://pro-football-reference.com/boxscores/201809160dal.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809160dal.json
# Trying to read https://pro-football-reference.com/boxscores/201809170chi.htm
# Couldn't parse cell
#  ^ Saving tables to /home/welced12/googledrive/nfl_data/devl/boxscores/201809170chi.json

# %%
# Extract parsed play-by-play from all of the individual boxscores

boxscore_path = '/home/welced12/googledrive/nfl_data/devl/pfr_boxscores'

gamepages = [
    f for f in os.listdir(boxscore_path) 
    if os.path.isfile(os.path.join(boxscore_path, f))
]
# Open json file, extracting play-by-play table
with open(os.path.join(boxscore_path,gamepages[0]), 'r') as f:
    g_dict = json.load(f)
pd.DataFrame(g_dict['pbp'])
# Out:
#                                 detail  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
# ..                                 ...
# 160                                NaN
# 161                                NaN
# 162                                NaN
# 163                                NaN
# 164                                NaN
# 165                                NaN
# 166                                NaN
# 167                                NaN
# 168                                NaN
# 169                                NaN
# 170                                NaN
# 171  Timeout #2 by Philadelphia Eagles
# 172                                NaN
# 173                                NaN
# 174                                NaN
# 175                                NaN
# 176                                NaN
# 177                                NaN
# 178                                NaN
# 179                                NaN
# 180      Timeout #2 by Atlanta Falcons
# 181                                NaN
# 182                                NaN
# 183      Timeout #3 by Atlanta Falcons
# 184                                NaN
# 185                                NaN
# 186                                NaN
# 187                                NaN
# 188                                NaN
# 189                                NaN
#
#                                               detail_a  \
# 0                                                  NaN
# 1                                         Jake Elliott
# 2                                        Logan Paulsen
# 3              Matt Ryan, Julio Jones, Malcolm Jenkins
# 4                           Julio Jones, Derek Barnett
# 5                     Devonta Freeman, Malcolm Jenkins
# 6                             Matt Ryan, Calvin Ridley
# 7                           Matt Ryan, Devonta Freeman
# 8                 Matt Ryan, Julio Jones, Ronald Darby
# 9         Devonta Freeman, Rodney McLeod, Sidney Jones
# 10        Devonta Freeman, Fletcher Cox, Derek Barnett
# 11                          Matt Ryan, Devonta Freeman
# 12    Devonta Freeman, Kamu Grugier-Hill, Jordan Hicks
# 13                          Darren Sproles, Keanu Neal
# 14           Nick Foles, Nelson Agholor, Robert Alford
# 15           Nick Foles, Darren Sproles, Ricardo Allen
# 16   Cameron Johnston, Justin Hardy, Kamu Grugier-H...
# 17                             Matt Ryan, Mohamed Sanu
# 18                          Tevin Coleman, Jalen Mills
# 19                             Matt Ryan, Sidney Jones
# 20                         Tevin Coleman, Ronald Darby
# 21             Matt Ryan, Tevin Coleman, Rodney McLeod
# 22              Matt Ryan, Austin Hooper, Nathan Gerry
# 23                                                 NaN
# 24                                           Matt Ryan
# 25                Matt Ryan, Chris Long, Derek Barnett
# 26                            Matt Ryan, Austin Hooper
# 27                                         Matt Bryant
# 28      Matthew Bosher, Shelton Gibson, Damontae Kazee
# 29                         Darren Sproles, Vic Beasley
# ..                                                 ...
# 160  Matt Ryan, Chris Long, Fletcher Cox, Matt Ryan...
# 161           Matt Ryan, Devonta Freeman, Corey Graham
# 162  Matthew Bosher, Darren Sproles, Eric Saubert, ...
# 163        Nick Foles, Nelson Agholor, Desmond Trufant
# 164            Nick Foles, Mike Wallace, Robert Alford
# 165        Nick Foles, Darren Sproles, Desmond Trufant
# 166          Nick Foles, Darren Sproles, Ricardo Allen
# 167                           Jay Ajayi, Grady Jarrett
# 168                      Corey Clement, Damontae Kazee
# 169                         Corey Clement, Deion Jones
# 170                                          Jay Ajayi
# 171                                                NaN
# 172                                          Jay Ajayi
# 173                                       Jake Elliott
# 174             Matt Ryan, Austin Hooper, Corey Graham
# 175              Matt Ryan, Julio Jones, Rodney McLeod
# 176                           Matt Ryan, Tevin Coleman
# 177                Matt Ryan, Chris Long, Jordan Hicks
# 178               Matt Ryan, Julio Jones, Ronald Darby
# 179                Matt Ryan, Julio Jones, Jalen Mills
# 180                                                NaN
# 181                            Matt Ryan, Fletcher Cox
# 182              Matt Ryan, Mohamed Sanu, Sidney Jones
# 183                                                NaN
# 184                                          Matt Ryan
# 185                             Matt Ryan, Julio Jones
# 186                                          Matt Ryan
# 187                            Matt Ryan, Jordan Hicks
# 188                             Matt Ryan, Julio Jones
# 189                                                NaN
#
#                                            detail_href  \
# 0                                                  NaN
# 1                              /players/E/ElliJa03.htm
# 2                              /players/P/PaulLo00.htm
# 3    /players/R/RyanMa00.htm, /players/J/JoneJu02.h...
# 4     /players/J/JoneJu02.htm, /players/B/BarnDe01.htm
# 5     /players/F/FreeDe00.htm, /players/J/JenkMa99.htm
# 6     /players/R/RyanMa00.htm, /players/R/RidlCa00.htm
# 7     /players/R/RyanMa00.htm, /players/F/FreeDe00.htm
# 8    /players/R/RyanMa00.htm, /players/J/JoneJu02.h...
# 9    /players/F/FreeDe00.htm, /players/M/McLeRo00.h...
# 10   /players/F/FreeDe00.htm, /players/C/CoxxFl00.h...
# 11    /players/R/RyanMa00.htm, /players/F/FreeDe00.htm
# 12   /players/F/FreeDe00.htm, /players/G/GrugKa00.h...
# 13    /players/S/SproDa00.htm, /players/N/NealKe01.htm
# 14   /players/F/FoleNi00.htm, /players/A/AghoNe00.h...
# 15   /players/F/FoleNi00.htm, /players/S/SproDa00.h...
# 16   /players/J/JohnCa02.htm, /players/H/HardJu00.h...
# 17    /players/R/RyanMa00.htm, /players/S/SanuMo00.htm
# 18    /players/C/ColeTe01.htm, /players/M/MillJa02.htm
# 19    /players/R/RyanMa00.htm, /players/J/JoneSi00.htm
# 20    /players/C/ColeTe01.htm, /players/D/DarbRo00.htm
# 21   /players/R/RyanMa00.htm, /players/C/ColeTe01.h...
# 22   /players/R/RyanMa00.htm, /players/H/HoopAu00.h...
# 23                                                 NaN
# 24                             /players/R/RyanMa00.htm
# 25   /players/R/RyanMa00.htm, /players/L/LongCh99.h...
# 26    /players/R/RyanMa00.htm, /players/H/HoopAu00.htm
# 27                           /players/B/bryanmat01.htm
# 28   /players/B/BoshMa00.htm, /players/G/GibsSh00.h...
# 29    /players/S/SproDa00.htm, /players/B/BeasVi00.htm
# ..                                                 ...
# 160  /players/R/RyanMa00.htm, /players/L/LongCh99.h...
# 161  /players/R/RyanMa00.htm, /players/F/FreeDe00.h...
# 162  /players/B/BoshMa00.htm, /players/S/SproDa00.h...
# 163  /players/F/FoleNi00.htm, /players/A/AghoNe00.h...
# 164  /players/F/FoleNi00.htm, /players/W/WallMi00.h...
# 165  /players/F/FoleNi00.htm, /players/S/SproDa00.h...
# 166  /players/F/FoleNi00.htm, /players/S/SproDa00.h...
# 167   /players/A/AjayJa00.htm, /players/J/JarrGr00.htm
# 168   /players/C/ClemCo00.htm, /players/K/KazeDa00.htm
# 169   /players/C/ClemCo00.htm, /players/J/JoneDe01.htm
# 170                            /players/A/AjayJa00.htm
# 171                                                NaN
# 172                            /players/A/AjayJa00.htm
# 173                            /players/E/ElliJa03.htm
# 174  /players/R/RyanMa00.htm, /players/H/HoopAu00.h...
# 175  /players/R/RyanMa00.htm, /players/J/JoneJu02.h...
# 176   /players/R/RyanMa00.htm, /players/C/ColeTe01.htm
# 177  /players/R/RyanMa00.htm, /players/L/LongCh99.h...
# 178  /players/R/RyanMa00.htm, /players/J/JoneJu02.h...
# 179  /players/R/RyanMa00.htm, /players/J/JoneJu02.h...
# 180                                                NaN
# 181   /players/R/RyanMa00.htm, /players/C/CoxxFl00.htm
# 182  /players/R/RyanMa00.htm, /players/S/SanuMo00.h...
# 183                                                NaN
# 184                            /players/R/RyanMa00.htm
# 185   /players/R/RyanMa00.htm, /players/J/JoneJu02.htm
# 186                            /players/R/RyanMa00.htm
# 187   /players/R/RyanMa00.htm, /players/H/HickJo00.htm
# 188   /players/R/RyanMa00.htm, /players/J/JoneJu02.htm
# 189                                                NaN
#
#                                            detail_text down exp_pts_after  \
# 0                                                  NaN  NaN           NaN
# 1                        kicks off 65 yards, touchback             -0.610
# 2     Penalty on brk, : False Start, 5 yards (no play)    1         0.280
# 3     pass complete short right to brk,  for 10 yar...    1         0.740
# 4              left end for 11 yards (tackle by brk, )    2         1.660
# 5             right end for 20 yards (tackle by brk, )    1         2.980
# 6            pass incomplete short right intended for     1         2.440
# 7             pass incomplete short left intended for     2         1.750
# 8     pass complete deep left to brk,  for 33 yards...    3         5.830
# 9       middle for 5 yards (tackle by brk,  and brk, )    1         5.910
# 10    left guard for no gain (tackle by brk,  and b...    2         5.170
# 11           pass incomplete short right intended for     3         3.550
# 12    left end for -1 yards (tackle by brk,  and br...    4         0.380
# 13                middle for 2 yards (tackle by brk, )    1        -0.630
# 14    pass complete short left to brk,  for 4 yards...    2        -0.720
# 15    pass incomplete short left intended for brk, ...    3        -2.490
# 16    punts 56 yards, returned by brk,  for 5 yards...    4        -2.650
# 17             pass incomplete deep left intended for     1         2.110
# 18            left guard for 5 yards (tackle by brk, )    2         2.080
# 19             right end for 6 yards (tackle by brk, )    3         3.380
# 20                      for -3 yards (tackle by brk, )    1         2.430
# 21    pass complete short left to brk,  for 26 yard...    2         4.910
# 22    pass complete short left to brk,  for 3 yards...    1         4.760
# 23                                                 NaN
# 24                                     pass incomplete    2         3.810
# 25    sacked by brk,  for -4 yards. Penalty on brk,...    3         4.720
# 26            pass incomplete short left intended for     3         3.040
# 27                             21 yard field goal good    4         3.000
# 28    kicks off 64 yards, returned by brk,  for 30 ...             -1.000
# 29               left end for 1 yard (tackle by brk, )    1         0.600
# ..                                                 ...  ...           ...
# 160   sacked by brk,  and brk,  for -8 yards. brk, ...    2        -3.130
# 161   pass complete short left to brk,  for 14 yard...    3        -1.440
# 162   punts 52 yards, returned by brk,  for 12 yard...    4        -1.990
# 163   pass complete short right to brk,  for 2 yard...    1         1.720
# 164   pass incomplete deep left intended for brk,  ...    2         1.030
# 165   pass complete short right to brk,  for 9 yard...    3         2.720
# 166   pass complete short right to brk,  for 6 yard...    1         2.990
# 167               middle for 2 yards (tackle by brk, )    2         2.540
# 168        right tackle for 21 yards (tackle by brk, )    3         4.650
# 169               middle for 3 yards (tackle by brk, )    1         4.520
# 170                   left end for 11 yards, touchdown    2         7.000
# 171                                                NaN
# 172  Two Point Attempt: brk,  right end, conversion...              1.000
# 173                      kicks off 65 yards, touchback             -0.610
# 174   pass complete short right to brk,  for 6 yard...    1         0.870
# 175   pass complete deep middle to brk,  for 36 yar...    2         3.380
# 176           pass incomplete short left intended for     1         2.840
# 177             sacked by brk,  and brk,  for -7 yards    2         1.220
# 178   pass complete deep left to brk,  for 18 yards...    3         4.110
# 179   pass complete short right to brk,  for 9 yard...    1         5.060
# 180                                                NaN
# 181                       sacked by brk,  for -7 yards    2         3.140
# 182   pass complete short left to brk,  for 10 yard...    3         4.910
# 183                                                NaN
# 184                                    pass incomplete    1         4.190
# 185         pass incomplete short middle intended for     2         3.130
# 186                                    pass incomplete    3         2.760
# 187   pass incomplete. Penalty on brk, : Illegal Co...    4         6.060
# 188           pass incomplete short left intended for     1         5.150
# 189                                                NaN  NaN           NaN
#
#     exp_pts_before location            onecell pbp_score_aw pbp_score_hm  \
# 0              NaN      NaN        1st Quarter          NaN          NaN
# 1            0.000   PHI 35                NaN            0            0
# 2            0.610   ATL 25                NaN            0            0
# 3            0.280   ATL 20                NaN            0            0
# 4            0.740   ATL 30                NaN            0            0
# 5            1.660   ATL 41                NaN            0            0
# 6            2.980   PHI 39                NaN            0            0
# 7            2.440   PHI 39                NaN            0            0
# 8            1.750   PHI 39                NaN            0            0
# 9            5.830    PHI 6                NaN            0            0
# 10           5.910    PHI 1                NaN            0            0
# 11           5.170    PHI 1                NaN            0            0
# 12           3.550    PHI 1                NaN            0            0
# 13          -0.380    PHI 2                NaN            0            0
# 14          -0.630    PHI 4                NaN            0            0
# 15          -0.720    PHI 8                NaN            0            0
# 16          -2.490    PHI 8                NaN            0            0
# 17           2.650   PHI 44                NaN            0            0
# 18           2.110   PHI 44                NaN            0            0
# 19           2.080   PHI 39                NaN            0            0
# 20           3.380   PHI 33                NaN            0            0
# 21           2.430   PHI 36                NaN            0            0
# 22           4.910   PHI 10                NaN            0            0
# 23                                         NaN
# 24           4.760    PHI 7                NaN            0            0
# 25           3.810    PHI 7                NaN            0            0
# 26           4.720    PHI 3                NaN            0            0
# 27           3.040    PHI 3                NaN            3            0
# 28           0.000   ATL 35                NaN            3            0
# 29           1.000   PHI 31                NaN            3            0
# ..             ...      ...                ...          ...          ...
# 160         -1.540   ATL 18                NaN           12           10
# 161         -3.130   ATL 15                NaN           12           10
# 162         -1.440   ATL 29                NaN           12           10
# 163          1.990   PHI 46                NaN           12           10
# 164          1.720   PHI 48                NaN           12           10
# 165          1.030   PHI 48                NaN           12           10
# 166          2.720   ATL 43                NaN           12           10
# 167          2.990   ATL 37                NaN           12           10
# 168          2.540   ATL 35                NaN           12           10
# 169          4.650   ATL 14                NaN           12           10
# 170          4.520   ATL 11                NaN           12           16
# 171                                        NaN           12           16
# 172          0.000    ATL 2                NaN           12           18
# 173          0.000   PHI 35                NaN           12           18
# 174          0.610   ATL 25                NaN           12           18
# 175          0.870   ATL 31                NaN           12           18
# 176          3.380   PHI 33                NaN           12           18
# 177          2.840   PHI 33                NaN           12           18
# 178          1.220   PHI 40                NaN           12           18
# 179          4.110   PHI 22                NaN           12           18
# 180                                        NaN           12           18
# 181          5.060   PHI 13                NaN           12           18
# 182          3.140   PHI 20                NaN           12           18
# 183                                        NaN           12           18
# 184          4.910   PHI 10                NaN           12           18
# 185          4.190   PHI 10                NaN           12           18
# 186          3.130   PHI 10                NaN           12           18
# 187          2.760   PHI 10                NaN           12           18
# 188          6.060    PHI 5                NaN           12           18
# 189            NaN      NaN  End of Regulation          NaN          NaN
#
#     qtr_time_remain qtr_time_remain_a qtr_time_remain_href quarter  \
# 0               NaN               NaN                  NaN     NaN
# 1               NaN             15:00               #pbp_1       1
# 2               NaN             15:00               #pbp_2       1
# 3               NaN             15:00               #pbp_3       1
# 4               NaN             14:22               #pbp_4       1
# 5               NaN             13:46               #pbp_5       1
# 6               NaN             13:10               #pbp_6       1
# 7               NaN             13:05               #pbp_7       1
# 8               NaN             13:01               #pbp_8       1
# 9               NaN             12:15               #pbp_9       1
# 10              NaN             11:41              #pbp_10       1
# 11              NaN             10:59              #pbp_11       1
# 12              NaN             10:55              #pbp_12       1
# 13              NaN             10:51              #pbp_13       1
# 14              NaN             10:10              #pbp_14       1
# 15              NaN              9:24              #pbp_15       1
# 16              NaN              9:20              #pbp_16       1
# 17              NaN              9:08              #pbp_17       1
# 18              NaN              9:02              #pbp_18       1
# 19              NaN              8:24              #pbp_19       1
# 20              NaN              7:38              #pbp_20       1
# 21              NaN              7:01              #pbp_21       1
# 22              NaN              6:19              #pbp_22       1
# 23                                NaN                  NaN
# 24              NaN              5:38              #pbp_23       1
# 25              NaN              5:32              #pbp_24       1
# 26              NaN              5:07              #pbp_25       1
# 27              NaN              5:03              #pbp_26       1
# 28              NaN              5:01              #pbp_27       1
# 29              NaN              4:50              #pbp_28       1
# ..              ...               ...                  ...     ...
# 160             NaN              6:31             #pbp_152       4
# 161             NaN              5:45             #pbp_153       4
# 162             NaN              5:04             #pbp_154       4
# 163             NaN              4:51             #pbp_155       4
# 164             NaN              4:48             #pbp_156       4
# 165             NaN              4:41             #pbp_157       4
# 166             NaN              4:32             #pbp_158       4
# 167             NaN              4:24             #pbp_159       4
# 168             NaN              3:57             #pbp_160       4
# 169             NaN              3:10             #pbp_161       4
# 170             NaN              2:25             #pbp_162       4
# 171             NaN              2:19             #pbp_163       4
# 172             NaN              2:19             #pbp_164       4
# 173             NaN              2:19             #pbp_165       4
# 174             NaN              2:19             #pbp_166       4
# 175             NaN              2:01             #pbp_167       4
# 176             NaN              1:54             #pbp_168       4
# 177             NaN              1:50             #pbp_169       4
# 178             NaN              1:25             #pbp_170       4
# 179             NaN              1:18             #pbp_171       4
# 180             NaN              1:18             #pbp_172       4
# 181             NaN              0:55             #pbp_173       4
# 182             NaN              0:29             #pbp_174       4
# 183             NaN              0:24             #pbp_175       4
# 184             NaN              0:24             #pbp_176       4
# 185             NaN              0:16             #pbp_177       4
# 186             NaN              0:11             #pbp_178       4
# 187             NaN              0:06             #pbp_179       4
# 188             NaN              0:01             #pbp_180       4
# 189             NaN               NaN                  NaN     NaN
#
#           rowclass yds_to_go
# 0    thead onecell       NaN
# 1              NaN
# 2          divider        10
# 3              NaN        15
# 4              NaN         5
# 5              NaN        10
# 6              NaN        10
# 7              NaN        10
# 8              NaN        10
# 9              NaN         6
# 10             NaN         1
# 11             NaN         1
# 12             NaN         1
# 13         divider        10
# 14             NaN         8
# 15             NaN         4
# 16             NaN         4
# 17         divider        10
# 18             NaN        10
# 19             NaN         5
# 20             NaN        10
# 21             NaN        13
# 22             NaN        10
# 23             NaN
# 24             NaN         7
# 25             NaN         7
# 26             NaN         3
# 27           score         3
# 28             NaN
# 29         divider        10
# ..             ...       ...
# 160            NaN        25
# 161            NaN        28
# 162            NaN        14
# 163        divider        10
# 164            NaN         8
# 165            NaN         8
# 166            NaN        10
# 167            NaN         4
# 168            NaN         2
# 169            NaN        10
# 170          score         7
# 171            NaN
# 172          score
# 173            NaN
# 174        divider        10
# 175            NaN         4
# 176            NaN        10
# 177            NaN        10
# 178            NaN        17
# 179            NaN        10
# 180            NaN
# 181            NaN         1
# 182            NaN         8
# 183            NaN
# 184            NaN        10
# 185            NaN        10
# 186            NaN        10
# 187            NaN        10
# 188            NaN         5
# 189  thead onecell       NaN
#
# [190 rows x 17 columns]

# %%
import pandas as pd
import json
import os

def get_secs_rem(df):
    # Get column for seconds remaining
    qtr = df['quarter'].values
    time_rem = df['qtr_time_remain_a'].values
    secs_rem= []
    
    for q, tr in zip(qtr, time_rem):
        try:
            [mins, secs] = tr.split(":")
            sr = 900*(4-int(q)) + 60*int(mins) + int(secs)
            secs_rem.append(sr)
        except:
            if 3600 in secs_rem:
                secs_rem.append(secs_rem[-1])
            else:
                secs_rem.append(3600)
                
    return secs_rem


def parse_possession( game_page ):
    df = pd.DataFrame(game_page['pbp'])
    # Get a list of which players are on which team.
    # This will be useful for determining possession later
    off_df = pd.DataFrame(game_page['player_offense'])
    def_df = pd.DataFrame(game_page['player_defense'])
    kick_df = pd.DataFrame(game_page['kicking'])
    cs = ['team','player_href']
    plyrs_df = pd.concat([ off_df[cs], def_df[cs], kick_df[cs] ])
    
    # Get home/away teams. Away team listed first for individual stats.
    home = off_df.team.values[-1]
    away = off_df.team.values[1]

    home_bool = [True if str(x)==home else False for x in plyrs_df.team]
    away_bool = [True if str(x)==away else False for x in plyrs_df.team]
    home_plyrs = plyrs_df[home_bool].player_href.values
    away_plyrs = plyrs_df[away_bool].player_href.values
    # If we have snap counts tables, those are even better
    if 'home_snap_counts' in game_page.keys():
        home_plyrs = pd.DataFrame(game_page['home_snap_counts']).player_href.values
        away_plyrs = pd.DataFrame(game_page['vis_snap_counts']).player_href.values
    
    # Make sure player names are lowercase
    home_plyrs = [str(x).lower() for x in home_plyrs]
    away_plyrs = [str(x).lower() for x in away_plyrs]
    
    # Go through play-by-play and track possession changes
    poss = []
    for i, (rc, plyrs, det) in enumerate(zip(df['rowclass'].values,
                                             df['detail_href'].values,
                                             df['detail_text'].values)):
        det = str(det).lower()
        # If rowclass is divider or score (or previous row is oncell),
        # ball is probably controlled by team of first player mentioned
        if poss == []:  # First entry in play-by-play
            poss.append(home)
        elif str(plyrs) == 'nan':
            # Continue possession from previous play
            poss.append(poss[-1])
        else:
            # First player mentioned probably started with possession
            prev_rc = df.rowclass.values[i-1]
            plyr1 = plyrs.split(", ")[0].lower()
            
            # If "No Play" and defensive pre-snap penalty in detail, 
            # continue possession from previous play
            if ("no play" in det) & ('offside' in det):
                poss.append(poss[-1])
                
            elif plyr1 in home_plyrs:
                poss.append(home)
            elif plyr1 in away_plyrs:
                poss.append(away)
            else:
                print("Couldn't match player",plyr1,"to a team")
                poss.append(poss[-1])
            
#            if (
#                ("divider" in str(rc)) or 
#                ("score" in str(rc)) or
#                ("onecell" in str(prev_rc))
#            ):
#                if plyr1 in home_plyrs:
#                    poss.append(home)
#                elif plyr1 in away_plyrs:
#                    poss.append(away)
#                else:
#                    print("Couldn't match player",plyr1)
#                    poss.append(poss[-1])
#            elif det.split()[0].lower() == 'penalty':
#                poss.append(poss[-1])
#            else:
#                # Just continue possession from previous play
#                poss.append(poss[-1])
    
    return poss


def get_defense( pbp_df ):
    home = pbp_df.home.values[1]
    away = pbp_df.away.values[1]
    poss = pbp_df['poss'].values
    
    defense = [home if off==away else away for off in poss]
    return defense


def get_poss_changes( pbp_df ):
    poss = pbp_df.poss.values
    pc = []
    for i, play in enumerate(poss[:-1]):
        if play == poss[i+1]:
            pc.append(False)
        else:
            pc.append(True)
    pc.append(False)
    return pc

def get_turnovers( pbp_df ):
    tos = [False for l in pbp_df.index]
    poss_changes = pbp_df.poss_change.values
    kickoffs = pbp_df.is_kickoff.values
    fgs = pbp_df.is_fieldgoal.values
    punts = pbp_df.is_punt.values
    for i, (pc, kick, punt, fg) in enumerate(zip(poss_changes, kickoffs, punts, fgs)):
        if ( pc and not (kick | punt | fg) ):
            tos[i] = True
    return tos


def get_fieldposition( pbp_df ):
    # Fieldposition from the offense's perspective
    off_fp = []
    for off, loc in zip(pbp_df.poss.values, pbp_df.location.values):
        if '50' in str(loc):
            off_fp.append(0)
        elif (
            (str(loc) in ['','nan']) or
            ("Location" in str(loc) )
        ):
            off_fp.append(0)
        elif len(loc) >= 4:
            side = loc.split()[0]
            ydline = int(loc.split()[1])
            if side == off:
                # Offense is on own side of field. fieldpos is negative
                off_fp.append( -1*(50-ydline) )
            else:
                # Offense is in opponent's territory
                off_fp.append( 50-ydline )
        else:
            print("not sure how to parse fieldpos",loc)
            off_fp.append(0)
            
    return off_fp


def found_pass(detail):
    d = detail.lower()
    pass_terms = ["pass", "sacked", "scramble",
                  "interception", "intercepted"]
    for term in pass_terms:
        if term in d:
            return True
    return False

def found_scramble(detail):
    d = detail.lower()
    if "scramble" in d:
        return True
    return False
    
def found_run(detail):
    d = detail.lower()
    run_terms = [
        "run ", "rush", "left tackle ","right tackle ",
        "up the middle ","middle for", "left end ", "right end ",
        "left guard ", "right guard "
    ]
    if not "scramble" in d:
        for term in run_terms:
            if term in d:
                return True
    return False

        
def found_punt(detail):
    d = detail.lower()
    if " punts " in d:
        return True
    elif " punt return" in d:
        return True
    return False
    
def found_fieldgoal(detail):
    d = detail.lower()
    if " field goal" in d:
        return True
    return False

def found_penalty(detail):
    d = detail.lower()
    if "penalty" in d:
        return True
    return False

def found_kickoff(detail):
    d = detail.lower()
    kickoff_terms = ["kicks off", 'kickoff', 'onside kicks']
    for kt in kickoff_terms:
        if kt in d:
            return True
    return False
    
def yds_run( detail ):
    words = detail.lower().split()
    # look for yardage in format "for X yards"
    for j, w in enumerate(words):
        if w == "for" and len(words) > j+2:
            if words[j+2].rstrip(".,") in ("yd","yds","yrd","yrds","yard","yards"):
                return int(words[j+1])
            # or "for no gain"
            elif "no" in words[j+1] and "gain" in words[j+2]:
                return 0
        
        # or "X yard run/rush"
        elif w in ("yd","yds","yrd","yrds","yard","yards") and len(words) >= j+2:
            if words[j+1].rstrip(".,") in ("run","rush"):
                return int(words[j-1])
        
    return "x"
    
def yds_passed( detail ):
    words = detail.lower().split()
    # look for yardage in format "for X yards"
    for j, w in enumerate(words):
        if w == "for" and len(words) > j+2:
            if words[j+2].rstrip(".,") in ("yd","yds","yrd","yrds","yard","yards"):
                return int(words[j+1])
            # or "for no gain"
            elif "no" in words[j+1] and "gain" in words[j+2]:
                return 0
            
        # or "X yard pass"
        elif w in ("yd","yds","yrd","yrds","yard","yards") and len(words) >= j+2:
            if words[j+1].rstrip(".,") in ("pass"):
                return int(words[j-1])

    # Or maybe pass went incomplete
    if "incomplete" in detail.lower():
        return 0
    
    # Or maybe pass was intercepted. In this case, just say yds_gained is zero
    elif ("intercepted" in detail.lower()) or ("interception" in detail.lower()):
        return 0
    
    return "x"


def parse_details(df):
    # Make a bunch of lists to be populated with details in-loop    
    df_len = len(df.down.values)
    is_parseable = [False for i in range(df_len)]
    is_run = [False for i in range(df_len)]
    is_scramble = [False for i in range(df_len)]
    is_pass = [False for i in range(df_len)]
    is_punt = [False for i in range(df_len)]
    is_fieldgoal = [False for i in range(df_len)]
    is_kickoff = [False for i in range(df_len)]
    is_penalty = [False for i in range(df_len)]
    yds_gained = ['x' for i in range(df_len)]
    
    # Loop through details, use logic tree to classify plays
    for i, (down, 
            detail_text, 
            detail_plyrs) in enumerate(zip(df.down.values,
                                           df.detail_text.values,
                                           df.detail_href.values)):
        detail_text = str(detail_text).lower()
        
        # Look for plays in downs 1-4
        if (str(down) != 'nan') and (str(down) != ''):
            
#            print("parsing",detail_text)            
            # Try and classify the play and parse yards gained        
            if found_scramble(detail_text):
                is_scramble[i] = True
                yds_gained[i] = yds_run(detail_text)
                
            if found_run(detail_text):
                is_run[i] = True
                yds_gained[i] = yds_run(detail_text)
                
            if found_pass(detail_text):
                is_pass[i] = True
                yds_gained[i] = yds_passed(detail_text)
                
            elif found_punt(detail_text):
                is_punt[i] = True
                
            elif found_fieldgoal(detail_text):
                is_fieldgoal[i] = True
        
        # Also check for kickoffs and penalties
        elif found_kickoff(detail_text):
            is_kickoff[i] = True
            
        if found_penalty(detail_text):
            is_penalty[i] = True
    
    
    for i, yds in enumerate(yds_gained):
        if (is_run[i] or is_pass[i] or is_scramble[i]) and (yds != 'x'):
            is_parseable[i] = True
        elif is_punt[i]:
            is_parseable[i] = True
        elif is_fieldgoal[i]:
            is_parseable[i] = True
            
    # Now write columns to the end of the DataFrame
    df['is_parseable'] = is_parseable
    df['is_run'] = is_run
    df['is_pass'] = is_pass
    df['is_scramble'] = is_scramble
    df['is_punt'] = is_punt
    df['is_fieldgoal'] = is_fieldgoal
    df['is_penalty'] = is_penalty
    df['is_kickoff'] = is_kickoff
    df['yds_gained'] = yds_gained
                            
    return df


def clean_yds_to_go( df ):
    y2g = []
    to_go = df['yds_to_go'].values
    ydline = df['off_fieldpos'].values
    for tg, yd in zip(to_go, ydline):
        if "goal" in str(tg).lower():
            y2g.append( 50 - int(yd) )
        else:
            y2g.append(tg)
            
    return y2g


def read_success( df ):
    frac = { 1:0.45, 2:0.65, 3:1.0, 4:1.0 }
    success = []
    tup = zip(
        df.is_parseable, df.down.values, 
        df.dist.values, df.yds_gained.values
    )
    for parseable, down, dist, gain in tup:
        if str(parseable) == 'True':
            # Play is 'success' if team gains
            # more yards than a particular fraction of the distance to 1st down
            try:
                if int(gain) >= frac[int(down)]*int(dist):
                    success.append(1)
                else:
                    success.append(0)
            except:
                success.append(0)
        else:
            success.append('nan')
            
    return success


def get_home_score_before( df ):
    scores = df.pbp_score_hm.shift(-1).values
    scores[0] = 0
    return scores

def get_away_score_before( df ):
    scores = df.pbp_score_aw.shift(-1).values
    scores[0] = 0
    return scores


def get_off_lead( df ):
    hm = df.home.values[0]
    aw = df.away.values[0]
    off_lead = [
        0 if (score_hm in [hm,''])
        else int(score_hm) - int(score_aw) if hm == off
        else int(score_aw) - int(score_hm) if aw == off
        else 0 for (off, score_hm, score_aw) in zip(
            df.poss.values, df.score_b4_hm.fillna(0).values, df.score_b4_aw.fillna(0).values
        )
    ]
    return off_lead

                

# Parse play-by-play for one pfr page with tables in json format\
def parse_pfr_pbp( game_page ):
    
    #print(game_page.keys())
    
    # Get raw play-by-play
    pbp_df = pd.DataFrame(game_page['pbp'])
    
    # Get home/away teams. Away team listed first for individual stats.
    home = pd.DataFrame(game_page['player_offense']).team.values[-1]
    away = pd.DataFrame(game_page['player_offense']).team.values[1]
    pbp_df['home'] = home
    pbp_df['away'] = away
    
    # Parse possession for each play
    pbp_df['poss'] = parse_possession( game_page )
    pbp_df['def'] = get_defense(pbp_df)
    # Parse fieldposition from offense's perspective
    pbp_df['off_fieldpos'] = get_fieldposition(pbp_df)
    # Get yards remaining in numerical form (convert goal-to-go situations)
    pbp_df['dist'] = pbp_df['yds_to_go'].values
    pbp_df['yds_to_go'] = clean_yds_to_go(pbp_df)
    # Parse seconds remaining
    pbp_df['secs_rem'] = get_secs_rem(pbp_df)
    # Sort out score before and after the play
    pbp_df['score_b4_hm'] = get_home_score_before(pbp_df)
    pbp_df['score_b4_aw'] = get_away_score_before(pbp_df)
    pbp_df.rename(
        {'pbp_score_hm':'score_after_hm', 'pbp_score_aw':'score_after_aw'},
        axis='columns', inplace=True
    )
    pbp_df['offense_lead'] = get_off_lead(pbp_df)
    # Parse details
    pbp_df = parse_details(pbp_df)
    # Track possession changes and turnovers
    pbp_df['poss_change'] = get_poss_changes(pbp_df)
    pbp_df['turnover'] = get_turnovers(pbp_df)
    # Determine 'success' of plays
    pbp_df['success'] = read_success(pbp_df)
    
    return pbp_df


# Read & parse pbp from individual game json files
#boxscore_path = '/home/welced12/googledrive/nfl_data/devl/pfr_boxscores'
boxscore_path = '/home/welced12/git/football_analytics/pfr_pages/boxscores'
gamepages = [
    f for f in os.listdir(boxscore_path) 
    if os.path.isfile(os.path.join(boxscore_path, f))
]

# Load information about these games
#gamelistpath = '/home/welced12/googledrive/nfl_data/devl/pfr_gamedata.json'
gamelistpath = '/home/welced12/git/football_analytics/pfr_pages/pfr_gamedata.json'
season_dfs = []
with open(gamelistpath, 'r') as f:
    gamehist_dict = json.load(f)
for ssn in gamehist_dict.keys():
    season_df = pd.DataFrame(gamehist_dict[ssn]['games'])
    season_df['season'] = ssn
    season_dfs.append(season_df)
gamehist_df = pd.concat(season_dfs)
#print(gamehist_df.info())

game_dfs = []
for i, gamefile in enumerate(gamepages[-1:]):
    with open(os.path.join(boxscore_path,gamefile), 'r') as f:
        g_dict = json.load(f)
    cs = ['detail_a','detail_text','rowclass','poss','off_fieldpos']
    game_df = parse_pfr_pbp(g_dict)
    
    # Add info about gid, season, week, and teams playing to pbp DF
    gid = gamefile.split('.')[0]
    bool_list = [True if (gid in str(link)) else False
                 for link in gamehist_df.boxscore_word_href.values]
    game_row = pd.DataFrame(gamehist_df[bool_list])
    
    game_df['gid'] = gid
    game_df['pid'] = [gid+str(idx) for idx in game_df.index]
    game_df['season'] = game_row['season'].values[0]
    game_df['week']  = game_row['week_num'].values[0]
    game_df.set_index('pid', inplace=True)
    
#    print(game_df.info())
    game_dfs.append(game_df)
    
    if i%100 == 0:
        print("Finished parsing",i,"games")


# Concatenate all play-by-play frames from individual games
all_pbp_df = pd.concat(game_dfs)
cool_cols = ['season','week','gid','home','away','score_b4_hm','score_b4_aw',
             'detail_a','detail_text','rowclass',
             'poss','poss_change',
             'off_fieldpos','down','dist','yds_to_go','yds_gained',
             'is_parseable','success']
print(all_pbp_df.info())
print(all_pbp_df[cool_cols].head(15))
print(all_pbp_df[cool_cols].tail(15))
pbp_filename = '/home/welced12/googledrive/nfl_data/devl/pfr_parsedplays.csv'
pbp_filename = '/tmp/test_parsedplays.csv'
all_pbp_df.to_csv(pbp_filename)
# Out:
# Couldn't match player /players/k/kingje00.htm to a team
# Couldn't match player /players/l/lloyrh44.htm to a team
# Couldn't match player /players/l/lloyrh44.htm to a team
# Couldn't match player /players/l/lloyrh44.htm to a team
# Finished parsing 0 games
# <class 'pandas.core.frame.DataFrame'>
# Index: 168 entries, 200911290nyj0 to 200911290nyj167
# Data columns (total 42 columns):
# detail                  11 non-null object
# detail_a                152 non-null object
# detail_href             152 non-null object
# detail_text             152 non-null object
# down                    163 non-null object
# exp_pts_after           163 non-null object
# exp_pts_before          163 non-null object
# location                163 non-null object
# onecell                 5 non-null object
# score_after_aw          163 non-null object
# score_after_hm          163 non-null object
# qtr_time_remain         14 non-null object
# qtr_time_remain_a       149 non-null object
# qtr_time_remain_href    149 non-null object
# quarter                 163 non-null object
# rowclass                45 non-null object
# yds_to_go               163 non-null object
# home                    168 non-null object
# away                    168 non-null object
# poss                    168 non-null object
# def                     168 non-null object
# off_fieldpos            168 non-null int64
# dist                    163 non-null object
# secs_rem                168 non-null int64
# score_b4_hm             163 non-null object
# score_b4_aw             163 non-null object
# offense_lead            168 non-null int64
# is_parseable            168 non-null bool
# is_run                  168 non-null bool
# is_pass                 168 non-null bool
# is_scramble             168 non-null bool
# is_punt                 168 non-null bool
# is_fieldgoal            168 non-null bool
# is_penalty              168 non-null bool
# is_kickoff              168 non-null bool
# yds_gained              168 non-null object
# poss_change             168 non-null bool
# turnover                168 non-null bool
# success                 168 non-null object
# gid                     168 non-null object
# season                  168 non-null object
# week                    168 non-null object
# dtypes: bool(10), int64(3), object(29)
# memory usage: 45.0+ KB
# None
#                season week           gid home away score_b4_hm score_b4_aw  \
# pid
# 200911290nyj0    2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj1    2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj2    2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj3    2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj4    2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj5    2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj6    2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj7    2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj8    2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj9    2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj10   2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj11   2009   12  200911290nyj  NYJ  CAR           0           0
# 200911290nyj12   2009   12  200911290nyj  NYJ  CAR           6           0
# 200911290nyj13   2009   12  200911290nyj  NYJ  CAR           7           0
# 200911290nyj14   2009   12  200911290nyj  NYJ  CAR           7           0
#
#                                                        detail_a  \
# pid
# 200911290nyj0                                               NaN
# 200911290nyj1                                         Jay Feely
# 200911290nyj2                    DeAngelo Williams, Shaun Ellis
# 200911290nyj3                DeAngelo Williams, Marques Douglas
# 200911290nyj4                   DeAngelo Williams, Jim Leonhard
# 200911290nyj5    Jake Delhomme, DeAngelo Williams, David Harris
# 200911290nyj6                       Jake Delhomme, David Harris
# 200911290nyj7                      Jonathan Stewart, Eric Smith
# 200911290nyj8        Jake Delhomme, Steve Smith, Darrelle Revis
# 200911290nyj9     DeAngelo Williams, Bryan Thomas, David Harris
# 200911290nyj10       Jake Delhomme, Dante Rosario, Drew Coleman
# 200911290nyj11   Jonathan Stewart, Ropati Pitoitua, Shaun Ellis
# 200911290nyj12      Jake Delhomme, Jonathan Stewart, Bart Scott
# 200911290nyj13  Jake Delhomme, Steve Smith, Darrelle Revis, NYJ
# 200911290nyj14                                        Jay Feely
#
#                                                       detail_text  \
# pid
# 200911290nyj0                                                 NaN
# 200911290nyj1                       kicks off 70 yards, touchback
# 200911290nyj2             left end for -3 yards (tackle by brk, )
# 200911290nyj3           left guard for -4 yards (tackle by brk, )
# 200911290nyj4          left tackle for 18 yards (tackle by brk, )
# 200911290nyj5    pass complete short right to brk,  for 6 yard...
# 200911290nyj6                        sacked by brk,  for -6 yards
# 200911290nyj7          left tackle for 13 yards (tackle by brk, )
# 200911290nyj8    pass incomplete short left intended for brk, ...
# 200911290nyj9    right tackle for 3 yards (tackle by brk,  and...
# 200911290nyj10   pass complete short right to brk,  for 13 yar...
# 200911290nyj11   right tackle for 1 yard (tackle by brk,  and ...
# 200911290nyj12   pass incomplete short middle intended for brk...
# 200911290nyj13   pass incomplete short left intended for brk, ...
# 200911290nyj14                             kicks extra point good
#
#                      rowclass poss  poss_change  off_fieldpos down dist  \
# pid
# 200911290nyj0   thead onecell  NYJ        False             0  NaN  NaN
# 200911290nyj1             NaN  NYJ         True           -20
# 200911290nyj2             NaN  CAR        False           -30    1   10
# 200911290nyj3             NaN  CAR        False           -33    2   13
# 200911290nyj4             NaN  CAR        False           -37    3   17
# 200911290nyj5             NaN  CAR        False           -19    1   10
# 200911290nyj6             NaN  CAR        False           -13    2    4
# 200911290nyj7             NaN  CAR        False           -19    3   10
# 200911290nyj8             NaN  CAR        False            -6    1   10
# 200911290nyj9             NaN  CAR        False            -6    2   10
# 200911290nyj10            NaN  CAR        False            -3    3    7
# 200911290nyj11            NaN  CAR        False            10    1   10
# 200911290nyj12            NaN  CAR        False            11    2    9
# 200911290nyj13          score  CAR         True            11    3    9
# 200911290nyj14  divider score  NYJ        False             0
#
#                yds_to_go yds_gained  is_parseable success
# pid
# 200911290nyj0        NaN          x         False     nan
# 200911290nyj1                     x         False     nan
# 200911290nyj2         10         -3          True       0
# 200911290nyj3         13         -4          True       0
# 200911290nyj4         17         18          True       1
# 200911290nyj5         10          6          True       1
# 200911290nyj6          4         -6          True       0
# 200911290nyj7         10         13          True       1
# 200911290nyj8         10          0          True       0
# 200911290nyj9         10          3          True       0
# 200911290nyj10         7         13          True       1
# 200911290nyj11        10          1          True       0
# 200911290nyj12         9          0          True       0
# 200911290nyj13         9         67          True       1
# 200911290nyj14                    x         False     nan
#                 season week           gid home away score_b4_hm score_b4_aw  \
# pid
# 200911290nyj153   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj154   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj155   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj156   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj157   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj158   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj159   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj160   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj161   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj162   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj163   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj164   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj165   2009   12  200911290nyj  NYJ  CAR          17           6
# 200911290nyj166   2009   12  200911290nyj  NYJ  CAR         NaN         NaN
# 200911290nyj167   2009   12  200911290nyj  NYJ  CAR         NaN         NaN
#
#                                                           detail_a  \
# pid
# 200911290nyj153      Jake Delhomme, Dwayne Jarrett, Dwayne Jarrett
# 200911290nyj154  Jake Delhomme, Muhsin Muhammad, Kerry Rhodes, NYJ
# 200911290nyj155  Thomas Jones, Dan Connor, Hollis Thomas, Nick ...
# 200911290nyj156        Thomas Jones, Tyler Brayton, James Anderson
# 200911290nyj157                                                NaN
# 200911290nyj158            Thomas Jones, Hollis Thomas, Jon Beason
# 200911290nyj159                                                NaN
# 200911290nyj160           Thomas Jones, Dan Connor, James Anderson
# 200911290nyj161                                                NaN
# 200911290nyj162                                  Steve Weatherford
# 200911290nyj163      Jake Delhomme, Muhsin Muhammad, Lito Sheppard
# 200911290nyj164     Jake Delhomme, DeAngelo Williams, Jim Leonhard
# 200911290nyj165                      Jake Delhomme, Dwayne Jarrett
# 200911290nyj166  Jake Delhomme, DeAngelo Williams, DeAngelo Wil...
# 200911290nyj167                                                NaN
#
#                                                        detail_text  \
# pid
# 200911290nyj153   pass complete deep left to brk,  for 28 yards...
# 200911290nyj154   pass incomplete deep left intended for brk,  ...
# 200911290nyj155   right guard for 1 yard (tackle by brk,  and b...
# 200911290nyj156   left guard for 1 yard (tackle by brk,  and br...
# 200911290nyj157                                                NaN
# 200911290nyj158     middle for 2 yards (tackle by brk,  and brk, )
# 200911290nyj159                                                NaN
# 200911290nyj160   left tackle for 2 yards (tackle by brk,  and ...
# 200911290nyj161                                                NaN
# 200911290nyj162                                     punts 66 yards
# 200911290nyj163   pass incomplete short right intended for brk,...
# 200911290nyj164   pass complete short right to brk,  for -2 yar...
# 200911290nyj165            pass incomplete deep left intended for
# 200911290nyj166   pass complete short middle to brk,  for 3 yar...
# 200911290nyj167                                                NaN
#
#                         rowclass poss  poss_change  off_fieldpos down dist  \
# pid
# 200911290nyj153          penalty  CAR        False            22    2   10
# 200911290nyj154              NaN  CAR         True            12    2   20
# 200911290nyj155  divider penalty  NYJ        False           -31    1   10
# 200911290nyj156              NaN  NYJ        False           -40    1   19
# 200911290nyj157              NaN  NYJ        False             0
# 200911290nyj158              NaN  NYJ        False           -39    2   18
# 200911290nyj159              NaN  NYJ        False             0
# 200911290nyj160              NaN  NYJ        False           -37    3   16
# 200911290nyj161              NaN  NYJ        False             0
# 200911290nyj162              NaN  NYJ         True           -35    4   14
# 200911290nyj163          divider  CAR        False           -31    1   10
# 200911290nyj164              NaN  CAR        False           -31    2   10
# 200911290nyj165              NaN  CAR        False           -33    3   12
# 200911290nyj166          penalty  CAR        False           -33    4   12
# 200911290nyj167    thead onecell  CAR        False             0  NaN  NaN
#
#                 yds_to_go yds_gained  is_parseable success
# pid
# 200911290nyj153        10         28          True       1
# 200911290nyj154        20          6          True       0
# 200911290nyj155        10          1          True       0
# 200911290nyj156        19          1          True       0
# 200911290nyj157                    x         False     nan
# 200911290nyj158        18          2          True       0
# 200911290nyj159                    x         False     nan
# 200911290nyj160        16          2          True       0
# 200911290nyj161                    x         False     nan
# 200911290nyj162        14          x          True       0
# 200911290nyj163        10          0          True       0
# 200911290nyj164        10         -2          True       0
# 200911290nyj165        12          0          True       0
# 200911290nyj166        12          3          True       0
# 200911290nyj167       NaN          x         False     nan
# /home/welced12/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:463: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
all_pbp_df.detail.unique()
# Out:
# array([nan, 'Detail', 'Timeout #1 by New York Jets',
#        'Timeout #2 by New York Jets', '',
#        'Timeout #1 by Carolina Panthers',
#        'Timeout #2 by Carolina Panthers',
#        'Timeout #3 by Carolina Panthers'], dtype=object)

# %%
bl = [True if 'penalty' in str(s).lower() else False for s in all_pbp_df.rowclass.values]
all_pbp_df[bl].detail_text.values
# Out:
# array([' punts 40 yards, returned by brk,  for 14 yards (tackle by brk, ). Penalty on brk, : Offensive Holding, 10 yards',
#        ' left guard for 4 yards (tackle by brk,  and brk, ). Penalty on brk, : Defensive Offside, 5 yards (no play)',
#        'Penalty on brk, : False Start, 5 yards (no play)',
#        ' pass incomplete deep middle intended for brk, . Penalty on brk, : Offensive Pass Interfere (Offsetting), Penalty on brk, : Defensive Pass Interfere (Offsetting) (no play)',
#        ' right tackle for 5 yards (tackle by brk, ). Penalty on brk, : Defensive Holding, 5 yards',
#        ' right end for 5 yards (tackle by brk, ). Penalty on brk, : Offensive Holding, 10 yards (no play)',
#        ' pass complete deep left to brk,  for 28 yards. Penalty on brk, : Offensive Pass Interfere, 10 yards (no play)',
#        ' right guard for 1 yard (tackle by brk,  and brk, ). Penalty on brk, : Offensive Holding, 9 yards (no play)',
#        ' pass complete short middle to brk,  for 3 yards. Penalty on brk, : Illegal Forward Pass'],
#       dtype=object)

# %%
bool_list = [True if 'goal' in str(d).lower() else False for d in all_pbp_df.dist.values]
all_pbp_df[bool_list][cool_cols]
# Out:
# Empty DataFrame
# Columns: [season, week, gid, home, away, detail_a, detail_text, poss, off_fieldpos, down, dist, yds_to_go, yds_gained]
# Index: []

# %%
all_pbp_df[all_pbp_df.off_fieldpos > 40][cool_cols]
# Out:
#     season week           gid home away  \
# 63    2017   15   201712160ka  KAN  LAC
# 64    2017   15   201712160ka  KAN  LAC
# 65    2017   15   201712160ka  KAN  LAC
# 115   2017   15   201712160ka  KAN  LAC
# 120   2017   15   201712160ka  KAN  LAC
# 121   2017   15   201712160ka  KAN  LAC
# 122   2017   15   201712160ka  KAN  LAC
# 123   2017   15   201712160ka  KAN  LAC
# 125   2017   15   201712160ka  KAN  LAC
# 152   2017   15   201712160ka  KAN  LAC
# 153   2017   15   201712160ka  KAN  LAC
# 22    2017    6  201710150htx  HOU  CLE
# 23    2017    6  201710150htx  HOU  CLE
# 24    2017    6  201710150htx  HOU  CLE
# 25    2017    6  201710150htx  HOU  CLE
# 26    2017    6  201710150htx  HOU  CLE
# 73    2017    6  201710150htx  HOU  CLE
# 74    2017    6  201710150htx  HOU  CLE
# 75    2017    6  201710150htx  HOU  CLE
# 76    2017    6  201710150htx  HOU  CLE
# 124   2017    6  201710150htx  HOU  CLE
# 125   2017    6  201710150htx  HOU  CLE
# 140   2017    6  201710150htx  HOU  CLE
# 168   2017    6  201710150htx  HOU  CLE
# 169   2017    6  201710150htx  HOU  CLE
# 170   2017    6  201710150htx  HOU  CLE
# 171   2017    6  201710150htx  HOU  CLE
# 175   2017    6  201710150htx  HOU  CLE
# 176   2017    6  201710150htx  HOU  CLE
# 54    2017    6  201710150nor  NOR  DET
# ..     ...  ...           ...  ...  ...
# 165   2017   17   201712310mi  MIN  CHI
# 166   2017   17   201712310mi  MIN  CHI
# 167   2017   17   201712310mi  MIN  CHI
# 168   2017   17   201712310mi  MIN  CHI
# 12    2018    5  201810070sea  SEA  LAR
# 13    2018    5  201810070sea  SEA  LAR
# 22    2018    5  201810070sea  SEA  LAR
# 23    2018    5  201810070sea  SEA  LAR
# 30    2018    5  201810070sea  SEA  LAR
# 45    2018    5  201810070sea  SEA  LAR
# 46    2018    5  201810070sea  SEA  LAR
# 47    2018    5  201810070sea  SEA  LAR
# 48    2018    5  201810070sea  SEA  LAR
# 64    2018    5  201810070sea  SEA  LAR
# 65    2018    5  201810070sea  SEA  LAR
# 104   2018    5  201810070sea  SEA  LAR
# 105   2018    5  201810070sea  SEA  LAR
# 114   2018    5  201810070sea  SEA  LAR
# 116   2018    5  201810070sea  SEA  LAR
# 117   2018    5  201810070sea  SEA  LAR
# 138   2018    5  201810070sea  SEA  LAR
# 60    2017   16   201712240ci  CIN  DET
# 61    2017   16   201712240ci  CIN  DET
# 92    2017   16   201712240ci  CIN  DET
# 104   2017   16   201712240ci  CIN  DET
# 106   2017   16   201712240ci  CIN  DET
# 107   2017   16   201712240ci  CIN  DET
# 115   2017   16   201712240ci  CIN  DET
# 116   2017   16   201712240ci  CIN  DET
# 151   2017   16   201712240ci  CIN  DET
#
#                                               detail_a  \
# 63                         Melvin Gordon, Allen Bailey
# 64                      Melvin Gordon, Daniel Sorensen
# 65                                       Melvin Gordon
# 115              Alex Smith, Kareem Hunt, Desmond King
# 120                        Kareem Hunt, Brandon Mebane
# 121                            Laurent Duvernay-Tardif
# 122                       Alex Smith, Demetrius Harris
# 123                            Alex Smith, Kareem Hunt
# 125                                    Harrison Butker
# 152                             Kareem Hunt, Joey Bosa
# 153                                        Kareem Hunt
# 22                     Lamar Miller, Christian Kirksey
# 23                                     Breno Giacomini
# 24                        Deshaun Watson, Ryan Griffin
# 25                        Deshaun Watson, Ryan Griffin
# 26          Shane Lechler, Jabrill Peppers, Dylan Cole
# 73     Deshaun Watson, Christian Kirksey, Jamar Taylor
# 74                      Deshaun Watson, Braxton Miller
# 75   Ka'imi Fairbairn, Briean Boddy-Calhoun, Briean...
# 76        Deshaun Watson, Ryan Griffin, Emmanuel Ogbah
# 124        D'Onta Foreman, Joe Schobert, Jamie Collins
# 125                    Deshaun Watson, DeAndre Hopkins
# 140  Deshaun Watson, Jay Prosch, Briean Boddy-Calho...
# 168          Lamar Miller, Joe Schobert, Danny Shelton
# 169                    Lamar Miller, Christian Kirksey
# 170                    Lamar Miller, Christian Kirksey
# 171    Shane Lechler, Jabrill Peppers, Kurtis Drummond
# 175          Kevin Hogan, David Njoku, Marcus Williams
# 176                          Kevin Hogan, Seth Devalve
# 54          Mark Ingram, Tahir Whitehead, Akeem Spence
# ..                                                 ...
# 165         Jordan Howard, Tom Johnson, Terence Newman
# 166                     Mitch Trubisky, Michael Burton
# 167        Mitch Trubisky, Tarik Cohen, Harrison Smith
# 168  Mitch Trubisky, Tarik Cohen, Linval Joseph, Ev...
# 12                           Todd Gurley, Bobby Wagner
# 13           Jared Goff, Todd Gurley, Frank Clark, SEA
# 22        Mike Davis, Cory Littleton, Michael Brockers
# 23                                          Mike Davis
# 30                                         Todd Gurley
# 45                      Todd Gurley, Bradley McDougald
# 46            Jared Goff, Todd Gurley, Tedric Thompson
# 47          Todd Gurley, Tedric Thompson, Bobby Wagner
# 48                                        Cairo Santos
# 64              Todd Gurley, Bobby Wagner, Jarran Reed
# 65                             Jared Goff, Cooper Kupp
# 104             Mike Davis, Mark Barron, Ndamukong Suh
# 105                        Russell Wilson, David Moore
# 114   Todd Gurley, Shaquill Griffin, Bradley McDougald
# 116                        Todd Gurley, Shamar Stephen
# 117                                        Todd Gurley
# 138                                        Todd Gurley
# 60            Andy Dalton, Teez Tabor, Tahir Whitehead
# 61                          Andy Dalton, Ezekiel Ansah
# 92                                       Randy Bullock
# 104                        Tion Green, Hardy Nickerson
# 106  Matthew Stafford, Kenny Golladay, William Jackson
# 107                                        Matt Prater
# 115                Andy Dalton, Tyler Boyd, Teez Tabor
# 116                           Andy Dalton, C.J. Uzomah
# 151                                         Tion Green
#
#                                            detail_text poss  off_fieldpos  \
# 63           left guard for -2 yards (tackle by brk, )  LAC            46
# 64           right guard for 4 yards (tackle by brk, )  LAC            44
# 65                       middle for 2 yards, touchdown  LAC            48
# 115   pass complete short left to brk,  for 3 yards...  KAN            47
# 120               middle for 5 yards (tackle by brk, )  KAN            44
# 121   Penalty on brk, : False Start, 5 yards (no play)  KAN            49
# 122         pass incomplete short middle intended for   KAN            44
# 123          pass incomplete short right intended for   KAN            44
# 125                            24 yard field goal good  KAN            44
# 152               middle for 2 yards (tackle by brk, )  KAN            43
# 153                      middle for 5 yards, touchdown  KAN            45
# 22           right tackle for 1 yard (tackle by brk, )  HOU            46
# 23    Penalty on brk, : False Start, 2 yards (no play)  HOU            45
# 24            pass incomplete short left intended for   HOU            47
# 25          pass incomplete short middle intended for   HOU            47
# 26    punts 41 yards, returned by brk,  for 17 yard...  HOU            47
# 73    left guard for 1 yard (tackle by brk,  and br...  HOU            48
# 74    pass complete short middle to brk,  for 1 yar...  HOU            49
# 75    kicks extra point good. Penalty on brk, : Run...  HOU            48
# 76   Two Point Attempt: brk,  pass complete to brk,...  HOU            49
# 124      middle for 1 yard (tackle by brk,  and brk, )  HOU            46
# 125   pass complete short middle to brk,  for 3 yar...  HOU            47
# 140   pass complete short right to brk,  for 18 yar...  HOU            41
# 168   right guard for 4 yards (tackle by brk,  and ...  HOU            48
# 169          right guard for 2 yards (tackle by brk, )  HOU            44
# 170          left tackle for no gain (tackle by brk, )  HOU            42
# 171   punts 53 yards, returned by brk,  for 11 yard...  HOU            42
# 175   pass incomplete short left intended for brk, ...  CLE            47
# 176   pass complete short left to brk,  for 3 yards...  CLE            47
# 54    right guard for no gain (tackle by brk,  and ...  NOR            49
# ..                                                 ...  ...           ...
# 165   left end for no gain (tackle by brk,  and brk, )  CHI            48
# 166      pass complete short left to brk,  for no gain  CHI            48
# 167   pass incomplete short left intended for brk, ...  CHI            48
# 168   pass complete short middle to brk,  for 1 yar...  CHI            48
# 12           right guard for 3 yards (tackle by brk, )  LAR            45
# 13    pass incomplete short middle intended for brk...  LAR            48
# 22      middle for 2 yards (tackle by brk,  and brk, )  SEA            42
# 23                       middle for 6 yards, touchdown  SEA            44
# 30                       middle for 2 yards, touchdown  LAR            48
# 45             right end for no gain (tackle by brk, )  LAR            41
# 46    pass complete short middle to brk,  for 8 yar...  LAR            41
# 47    left guard for no gain (tackle by brk,  and b...  LAR            49
# 48                             19 yard field goal good  LAR            49
# 64    left tackle for 3 yards (tackle by brk,  and ...  LAR            41
# 65    pass complete short right to brk,  for 6 yard...  LAR            44
# 104   left end for 3 yards (tackle by brk,  and brk, )  SEA            44
# 105   pass complete short right to brk,  for 3 yard...  SEA            47
# 114    middle for -3 yards (tackle by brk,  and brk, )  LAR            49
# 116          left tackle for 2 yards (tackle by brk, )  LAR            46
# 117                 left tackle for 2 yards, touchdown  LAR            48
# 138                  left guard for 5 yards, touchdown  LAR            45
# 60     left end for 1 yard (tackle by brk,  and brk, )  CIN            42
# 61                        sacked by brk,  for -4 yards  CIN            43
# 92                             27 yard field goal good  CIN            41
# 104         right tackle for 2 yards (tackle by brk, )  DET            43
# 106   pass incomplete short middle intended for brk...  DET            45
# 107                            23 yard field goal good  DET            45
# 115   pass complete short right to brk,  for 6 yard...  CIN            43
# 116   pass complete short middle to brk,  for 1 yar...  CIN            49
# 151                 left tackle for 5 yards, touchdown  DET            45
#
#     down dist yds_to_go yds_gained  is_parseable success
# 63     1    4         4         -2          True       0
# 64     2    6         6          4          True       1
# 65     3    2         2          2          True       1
# 115    1    3         3          3          True       1
# 120    1    6         6          5          True       1
# 121    2    1         1          x         False     nan
# 122    2    6         6          0          True       0
# 123    3    6         6          0          True       0
# 125    4    6         6          x          True       0
# 152    2    7         7          2          True       0
# 153    3    5         5          5          True       1
# 22     1   10        10          1          True       0
# 23     2    9         9          x         False     nan
# 24     2   11        11          0          True       0
# 25     3   11        11          0          True       0
# 26     4   11        11          x          True       0
# 73     1    2         2          1          True       1
# 74     2    1         1          1          True       1
# 75                               x         False     nan
# 76                               x         False     nan
# 124    2    4         4          1          True       0
# 125    3    3         3          3          True       1
# 140    2   12        12         18          True       1
# 168    1   10        10          4          True       0
# 169    2    6         6          2          True       0
# 170    3    4         4          0          True       0
# 171    4    4         4          x          True       0
# 175    1    3         3          0          True       0
# 176    2    3         3          3          True       1
# 54     1    1         1          0          True       0
# ..   ...  ...       ...        ...           ...     ...
# 165    1    2         2          0          True       0
# 166    2    2         2          0          True       0
# 167    3    2         2          0          True       0
# 168    4    2         2          1          True       0
# 12     1    5         5          3          True       1
# 13     2    2         2         26          True       1
# 22     3    2         2          2          True       1
# 23     1    6         6          6          True       1
# 30     1    2         2          2          True       1
# 45     1    9         9          0          True       0
# 46     2    9         9          8          True       1
# 47     3    1         1          0          True       0
# 48     4    1         1          x          True       0
# 64     1    9         9          3          True       0
# 65     2    6         6          6          True       1
# 104    1    6         6          3          True       1
# 105    2    3         3          3          True       1
# 114    1    1         1         -3          True       0
# 116    2    4         4          2          True       0
# 117    3    2         2          2          True       1
# 138    1    5         5          5          True       1
# 60     1    8         8          1          True       0
# 61     2    7         7         -4          True       0
# 92     2    7         7          x          True       0
# 104    2    4         4          2          True       0
# 106    3    2         2          0          True       0
# 107    4    2         2          x          True       0
# 115    1    7         7          6          True       1
# 116    2    1         1          1          True       1
# 151    1    5         5          5          True       1
#
# [3426 rows x 15 columns]
