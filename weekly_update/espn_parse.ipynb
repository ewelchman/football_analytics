# %%
import pandas as pd
import os

drivesfile = "/home/welced12/googledrive/nfl_data/devl/espn_drives.json"
if os.path.isfile(drivesfile):
    drives_df = pd.read_json(drivesfile)

# %%
drives_df.sample(5)
# Out:
#              away  away_score_after  away_score_before  drive home  \
# 320909018-3    NO                 7                  7      3  WSH
# 321118034-4   HOU                 7                  7      4  JAX
# 321125004-3   CIN                14                  7      3  OAK
# 300103020-12  NYJ                27                 27     13  CIN
# 311124033-10  BAL                 6                  6     10   SF
#
#               home_score_after  home_score_before offense  plays       result  \
# 320909018-3                 10                  3     WSH      1    Touchdown
# 321118034-4                  7                  0     HOU      4         Punt
# 321125004-3                  0                  0     CIN      9    Touchdown
# 300103020-12                 0                  0     CIN      3         Punt
# 311124033-10                 3                  3     BAL      2  End of Half
#
#               time  yds_gained     gameid
# 320909018-3   0:21          88  320909018
# 321118034-4   2:35          18  321118034
# 321125004-3   4:28          88  321125004
# 300103020-12  2:03           2  300103020
# 311124033-10  0:11          -1  311124033

# %%
def find_endofhalves(result_list):
    is_eoh = []
    for outcome in [x.lower() for x in result_list]:
        eoh = 0
        if "end of half" in outcome:
            eoh = 1
        elif "end of game" in outcome:
            eoh = 1
        is_eoh.append(eoh)
        
    return is_eoh

drives_df['eoh'] = find_endofhalves(drives_df['result'].values)

# %%
drives_df[drives_df.eoh==1].sample(5)
# Out:
#              away  away_score_after  away_score_before  drive home  \
# 291025005-8   CLE                 3                  3      8   GB
# 311016004-9   CIN                10                 10      9  IND
# 291214025-14   SF                17                 17     14  ARI
# 321021004-9   CIN                14                 14      9  PIT
# 310925004-10  CIN                 3                  3     10   SF
#
#               home_score_after  home_score_before offense  plays       result  \
# 291025005-8                 21                 21     CLE      7  End of Half
# 311016004-9                  7                  7     CIN      1  End of Half
# 291214025-14                 0                  0      SF      3  End of Half
# 321021004-9                 14                 14     CIN      2  End of Half
# 310925004-10                 0                  0     CIN      3  End of Half
#
#               time  yds_gained     gameid  eoh
# 291025005-8   1:56           6  291025005    1
# 311016004-9   0:00           0  311016004    1
# 291214025-14  0:07           9  291214025    1
# 321021004-9   0:24          -1  321021004    1
# 310925004-10  1:00          10  310925004    1

# %%
def get_time_in_secs(value_list):
    top_secs = [0 for x in value_list]
    for i, time in enumerate(value_list):
        (mins,secs) = time.split(":")
        total_seconds = int(secs) + 60*int(mins)
        top_secs[i] = total_seconds
    return top_secs

drives_df['time_in_secs'] = get_time_in_secs(drives_df.time.values)

drives_df[['time','time_in_secs']].sample(5)
# Out:
#               time  time_in_secs
# 310912015-19  0:51            51
# 320101018-4   5:21           321
# 290920012-12  2:53           173
# 330915033-9   1:51           111
# 320930021-16  5:24           324

# %%
drives_df.sort_values(by=['gameid','drive'],
                      ascending=['False','True']).head(25)
# Out:
#              away  away_score_after  away_score_before  drive home  \
# 290910023-0   PIT                 0                  0      0  TEN
# 290910023-1   PIT                 0                  0      1  TEN
# 290910023-2   PIT                 0                  0      2  TEN
# 290910023-3   PIT                 0                  0      3  TEN
# 290910023-4   PIT                 0                  0      4  TEN
# 290910023-5   PIT                 0                  0      5  TEN
# 290910023-7               Punt  2:02           0  290910023    0           122
# 290910023-8               Punt  5:50          33  290910023    0           350
# 290910023-9          Missed FG  4:59          52  290910023    0           299
# 290910023-10         Touchdown  0:52          79  290910023    0            52
# 290910023-11         Touchdown  0:34          71  290910023    0            34
# 290910023-12  Intercepted Pass  0:48          18  290910023    0            48
# 290910023-13            Fumble  3:03          37  290910023    0           183
# 290910023-14              Punt  1:45           9  290910023    0           105
# 290910023-15              Punt  1:52          -1  290910023    0           112
# 290910023-16              Punt  2:43          11  290910023    0           163
# 290910023-17              Punt  3:25          19  290910023    0           205
# 290910023-18              Punt  1:43           8  290910023    0           103
# 290910023-19        Field Goal  3:43          36  290910023    0           223
# 290910023-20        Field Goal  8:06          56  290910023    0           486
# 290910023-21              Punt  1:07          12  290910023    0            67
# 290910023-22            Fumble  0:59          24  290910023    0            59
# 290910023-23       End of Half  0:51           0  290910023    1            51
# 290910023-24        Field Goal  4:32          63  290910023    0           272

# %%
def get_secs_played(df):
    secs_played = {}
    for gid in df.gameid.unique():
        gamedf = df.loc[df.gameid==gid,:].sort_values(by='drive',
                                                ascending=True)
        # Keep track of secs_played at the beginning of each drive
        played = 0
        for driveid in gamedf.index:
            secs_played[driveid] = played
            played += gamedf.loc[driveid,'time_in_secs']
    return secs_played

def get_secs_rem(df):
    for gid in df.gameid.unique():
        timelist = []
        gamedf = df[df.gameid==gid].sort_values(by=['drive'],
                                                ascending=True)
        # Get index of drives ending halves
        nums = gamedf[gamedf.eoh==1]['drive'].values
        print(nums)
        print(sum(gamedf.time_in_secs.values))
        for i, drivenum in enumerate(nums):
            # For each half, count time down from 1800
            secs_rem = 1800 if i<2 else 900
            last_drive = nums[i+1] if len(nums)>i+1 else gamedf.drive.max()
            halfdf = gamedf[
                (gamedf.drive >= drivenum) &
                (gamedf.drive < last_drive)
            ]
            print(halfdf)

newdict = get_secs_played(drives_df[drives_df.gameid==290910023])
newdict
# Out:
# {'290910023-0': 0,
#  '290910023-1': 104,
#  '290910023-10': 1664,
#  '290910023-11': 1716,
#  '290910023-12': 1750,
#  '290910023-13': 1798,
#  '290910023-14': 1981,
#  '290910023-15': 2086,
#  '290910023-16': 2198,
#  '290910023-17': 2361,
#  '290910023-18': 2566,
#  '290910023-19': 2669,
#  '290910023-2': 216,
#  '290910023-20': 2892,
#  '290910023-21': 3378,
#  '290910023-22': 3445,
#  '290910023-23': 3504,
#  '290910023-24': 3555,
#  '290910023-3': 400,
#  '290910023-4': 495,
#  '290910023-5': 610,
#  '290910023-6': 801,
#  '290910023-7': 893,
#  '290910023-8': 1015,
#  '290910023-9': 1365}

# %%
# To most correctly get seconds remaining at the beginning of a drive,
# get the parsed play-by-play json file.
parsedplays_file = '/home/welced12/googledrive/nfl_data/devl/espn_parsedplays.json'
pbp_df = pd.read_json(parsedplays_file)
pbp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 351800 entries, 290910023-0 to 400981391-99
# Data columns (total 26 columns):
# downdist             351800 non-null object
# detail               351800 non-null object
# play_num             351800 non-null int64
# home                 351800 non-null object
# away                 351800 non-null object
# possession           351800 non-null object
# home_score_before    351800 non-null int64
# away_score_before    351800 non-null int64
# home_score_after     351800 non-null int64
# away_score_after     351800 non-null int64
# drive_num            351800 non-null int64
# gameid               351800 non-null int64
# down                 351800 non-null int64
# dist                 351800 non-null object
# home_fieldpos        351800 non-null int64
# qtr                  351800 non-null object
# time_rem             351800 non-null object
# secs_rem             351800 non-null int64
# is_parseable         351800 non-null object
# is_run               351800 non-null object
# is_scramble          351800 non-null object
# is_pass              351800 non-null object
# is_punt              351800 non-null object
# is_fieldgoal         351800 non-null object
# runpass_play         351800 non-null object
# yds_gained           351800 non-null object
# dtypes: int64(10), object(16)
# memory usage: 72.5+ MB

# %%
pbp_df[pbp_df.play_num==1].sample(5)
# Out:
#                            downdist  \
# 400791622-0                      []
# 400554416-164                    []
# 400874597-35    [1st & 10 at SF 12]
# 400951672-36   [1st & 10 at DAL 41]
# 400874699-106                    []
#
#                                                           detail  play_num  \
# 400791622-0    (15:00 - 1st) N.Novak kicks 62 yards from HST ...         1
# 400554416-164  (0:23 - 4th) N.Folk kicks 65 yards from NYJ 35...         1
# 400874597-35   (3:22 - 1st)  (Shotgun) D.Brees pass short lef...         1
# 400951672-36   (1:52 - 1st)  A.Morris up the middle to DAL 45...         1
# 400874699-106  (8:05 - 3rd) S.Hauschka kicks 56 yards from SE...         1
#
#               home away possession  home_score_before  away_score_before  \
# 400791622-0    HOU  CIN        CIN                  0                  0
# 400554416-164  NYJ  MIN        MIN                 24                 24
# 400874597-35    NO   SF         NO                  7                  3
# 400951672-36   WSH  DAL        DAL                  0                  0
# 400874699-106  SEA   SF         SF                 22                 14
#
#                home_score_after  away_score_after    ...      time_rem  \
# 400791622-0                   0                 0    ...         15:00
# 400554416-164                24                24    ...          0:23
# 400874597-35                 14                 3    ...          3:22
# 400951672-36                  0                 7    ...          1:52
# 400874699-106                22                14    ...          8:05
#
#                secs_rem  is_parseable is_run  is_scramble is_pass is_punt  \
# 400791622-0        3600         False  False        False   False   False
# 400554416-164        23         False  False        False   False   False
# 400874597-35       2902          True  False        False    True   False
# 400951672-36       2812          True   True        False   False   False
# 400874699-106      1385         False  False        False   False   False
#
#                is_fieldgoal runpass_play yds_gained
# 400791622-0           False        False          0
# 400554416-164         False        False          0
# 400874597-35          False         True          7
# 400951672-36          False         True          4
# 400874699-106         False        False          0
#
# [5 rows x 26 columns]

# %%
relevant_cols = ['gameid','drive_num','play_num','home','away',
                 'possession','secs_rem']
firstplays = pbp_df.loc[ pbp_df['play_num'] == 1, relevant_cols ]
firstplays['driveid'] = firstplays.gameid.astype(str)+"-"+firstplays.drive_num.astype(str)
# Merge this into the drives DataFrame
right_df = firstplays[['driveid','secs_rem']]
merged_drives = pd.merge( drives_df, right_df,
                          how='left',
                          left_index=True,
                          right_on='driveid')
merged_drives.set_index('driveid', inplace=True)
merged_drives.sample(5)
# Out:
#              away  away_score_after  away_score_before  drive home  \
# driveid
# 311113003-0   CHI                 0                  0      0  DET
# 320101021-9   PHI                 3                  3      9  WSH
# 311113011-11  IND                 3                  3     11  JAX
# 300103022-11  ARI                 0                  0     12   GB
# 291220012-12   KC                24                 24     12  CLE
#
#               home_score_after  home_score_before offense  plays      result  \
# driveid
# 311113003-0                  0                  0     DET      4      Fumble
# 320101021-9                  0                  0     WSH     10  Blocked FG
# 311113011-11                 3                  3     JAX      3        Punt
# 300103022-11                33                 26      GB     14   Touchdown
# 291220012-12                20                 19      KC      7        Punt
#
#               time  yds_gained     gameid  eoh  time_in_secs  secs_rem
# driveid
# 311113003-0   2:50          46  311113003    0           170    3600.0
# 320101021-9   4:45          52  320101021    0           285    2438.0
# 311113011-11  1:12          -2  311113011    0            72    2077.0
# 300103022-11  7:31          94  300103022    0           451    1800.0
# 291220012-12  2:05          32  291220012    0           125    1951.0

# %%
# Parse individual plays
rawplays_file = "/home/welced12/googledrive/nfl_data/devl/espn_rawplays.json"
rawplays_df = pd.read_json(rawplays_file)

# %%
rawplays_df.sample(5)
# Out:
#                            downdist  \
# 400874561-140   [3rd & 1 at OAK 12]
# 330909028-103  [3rd & 11 at WSH 19]
# 321014001-40    [2nd & 6 at OAK 21]
# 331013016-162  [2nd & 10 at CAR 19]
# 400874541-87   [1st & 10 at MIA 26]
#
#                                                           detail  play_num  \
# 400874561-140  (5:26 - 4th)  G.Cherilus reported in as eligib...        11
# 330909028-103  (14:07 - 3rd)  R.Griffin pass short left inten...         5
# 321014001-40   (11:14 - 2nd) (No Huddle, Shotgun) M.Ryan pass...         9
# 331013016-162  (0:30 - 4th) D.Anderson kneels to CAR 18 for -...         2
# 400874541-87   (0:53 - 2nd)  (No Huddle, Shotgun) R.Tannehill...         3
#
#               home away possession  home_score_before  away_score_before  \
# 400874561-140  OAK   TB         TB                 17                 16
# 330909028-103  PHI  WSH        WSH                 26                  7
# 321014001-40   OAK  ATL        ATL                  3                  0
# 331013016-162  CAR  MIN        CAR                 35                 10
# 400874541-87   MIA   NE        MIA                  0                 24
#
#                home_score_after  away_score_after  drive_num     gameid
# 400874561-140                17                24         19  400874561
# 330909028-103                26                 7         16  330909028
# 321014001-40                  3                 7          6  321014001
# 331013016-162                35                10         19  331013016
# 400874541-87                  3                24         13  400874541

# %%
def parse_downdist(df):
    # Given a DataFrame, return dictionaries for down, distance, and fieldpos
    down = []
    dist = []
    home_fieldpos = []
    
    hometeam = df.home.values
    awayteam = df.away.values
    
    def get_fieldpos(teamside, ydline, j):
        if teamside == hometeam[j]:
            # Ball is on home team's half. Location should be negative
            return -1*(50-ydline)
        elif teamside == awayteam[j]:
            return 50-ydline
        else:
            return "x"
        
    
    for j, c in enumerate(df.downdist.values):
        
        x = str(c).strip("[]'")
        # Check for an empty list. This probably means end of qtr/half
        if (not x) or x==None:
            down.append(0)
            dist.append(0)
            home_fieldpos.append(0)
            
        else:
            x = [x]
            pieces = x[0].split()
            
            # Parse down
            if not (pieces[0][0].isalpha() or pieces[0][0]=="&"):  # Check if first char is alpha
                # Then first char is numeric. This is down number
                down.append(int(pieces[0][0]))
            else:
                down.append(0)
                
            # Parse distance
            for i, word in enumerate(pieces):
                if (word == "and") or (word == "&"):
                    dist.append(pieces[i+1])  # Keep as string to preserve goal-to-go
            
            # Get fieldposition from home team's perspective
            for i, word in enumerate(pieces):
                if word == "at":
                    if pieces[i+1]=='50':
                        home_fieldpos.append(0)
                    else:
                        teamside = pieces[i+1]
                        ydline = int(pieces[i+2])
                        
                        fieldpos = get_fieldpos(teamside,ydline,j)
                        
                        if fieldpos=="x":
                            # Cases to account for team name not matching description
                            if teamside == "LAR":
                                teamside = "STL"
                            elif teamside == "LAC":
                                teamside = "SD"
                            fieldpos = get_fieldpos(teamside,ydline,j)
                            
                        if fieldpos=="x":
                            home_fieldpos.append(0)
                            print(pieces)
                            print("Failed to find side of field correctly")
                            
                        else:
                            home_fieldpos.append(fieldpos)
                            
    return (down, dist, home_fieldpos)

# %%
def parse_time_rem(df):
    detail = df.detail.values
    
    qtr = []
    time_rem = []
    
    for d in detail:
        try:
            if (not d) or (d == None):
                # detail is an empty list
                qtr.append(0)
                time_rem.append("0:00")
        
            else:
                pieces = d.split()
                if pieces[0][0] == "E":
                    # Found End of Quarter/Overtime line
                    qtr.append(0)
                    time_rem.append("0:00")

                elif pieces[0][0] == "(":
                    # Found beginning of standard "(1:23 - 4th)" template
                    qtr.append(pieces[2][0])
                    time_rem.append(pieces[0].lstrip("("))
            
                else:
                    # Not sure what this is, so just be safe and go to 0:00 rem in 4th
                    print(d)
                    qtr.append(0)
                    time_rem.append("0:00")
            
        except:
            print("Default parse failed for:")
            print(d)
            qtr.append(0)
            time_rem.append("0:00")       
            
    return (qtr, time_rem)


def get_secs_rem(df):
    qtr = df.qtr.values
    time_rem = df.time_rem.values
    
    secs_rem = []
    
    for i, tr in enumerate(time_rem):
        if qtr[i] in ['1','2','3','4']:
            q = int(qtr[i])
        elif qtr[i] == 'O':
            q = 4
        else:
            q = 0
        mins = int(tr.split(":")[0])
        secs = int(tr.split(":")[1])
        secs_rem.append( 900*(4-q) + 60*mins + secs )
        
    return secs_rem

# %%
cols = ['downdist','down','dist','home_fieldpos','detail','qtr','time_rem','secs_rem']
parsed_df[cols].sample(25)
# Out:
#                            downdist  down  dist  home_fieldpos  \
# 400951586-14    [3rd & 1 at ATL 35]     3     1             15
# 321202007-0     [1st & 10 at TB 20]     1    10            -30
# 400951778-40                     []     0     0              0
# 330915019-57    [3rd & 12 at DEN 8]     3    12            -42
# 290920030-106  [3rd & 15 at JAX 45]     3    15              5
# 321007012-18    [2nd & 10 at BAL 9]     2    10            -41
# 291221028-12     [3rd & 3 at WSH 9]     3     3             41
# 400874517-63   [1st & 10 at JAX 32]     1    10            -18
# 331124008-144  [1st & 10 at DET 36]     1    10             14
# 331222029-19    [3rd & 6 at CAR 15]     3     6             35
# 400874670-172  [4th & 10 at OAK 44]     4    10              6
# 400554449-141    [3rd & 5 at DEN 7]     3     5            -43
# 400791560-55    [2nd & 7 at OAK 23]     2     7             27
# 400951773-38   [1st & 10 at LAR 34]     1    10            -16
# 400951770-20    [1st & 10 at TB 37]     1    10            -13
# 330915013-88   [1st & 10 at JAX 49]     1    10             -1
# 400791685-145  [2nd & 14 at ATL 27]     2    14            -23
# 400791655-115       741
# 321111025-204      3600
# 320923003-73       1871

# %%
# Parse play type/details

def found_pass(detail):
    d = detail.lower()
    pass_terms = [" pass", " sacked", " scramble",
                  "interception", "intercepted"]
    for term in pass_terms:
        if term in d:
            return True
    return False

def found_scramble(detail):
    d = detail.lower()
    if " scramble" in d:
        return True
    return False
    
def found_run(detail):
    d = detail.lower()
    run_terms = [" run ", " rush", " left tackle ", " up the middle ",
                 " left end ", " right end ", " left guard ", " right guard "]
    if not " scramble" in d:
        for term in run_terms:
            if term in d:
                return True
    return False

        
def found_punt(detail):
    d = detail.lower()
    if " punts " in d:
        return True
    elif " punt return" in d:
        return True
    return False
    
def found_fieldgoal(detail):
    d = detail.lower()
    if " field goal" in d:
        return True
    return False

def yds_run( detail ):
    words = detail.lower().split()
    # look for yardage in format "for X yards"
    for j, w in enumerate(words):
        if w == "for" and len(words) > j+2:
            if words[j+2].rstrip(".,") in ("yd","yds","yrd","yrds","yard","yards"):
                return int(words[j+1])
            # or "for no gain"
            elif "no" in words[j+1] and "gain" in words[j+2]:
                return 0
        
        # or "X yard run/rush"
        elif w in ("yd","yds","yrd","yrds","yard","yards") and len(words) >= j+2:
            if words[j+1].rstrip(".,") in ("run","rush"):
                return int(words[j-1])
        
    return "x"
    
def yds_passed( detail ):
    words = detail.lower().split()
    # look for yardage in format "for X yards"
    for j, w in enumerate(words):
        if w == "for" and len(words) > j+2:
            if words[j+2].rstrip(".,") in ("yd","yds","yrd","yrds","yard","yards"):
                return int(words[j+1])
            # or "for no gain"
            elif "no" in words[j+1] and "gain" in words[j+2]:
                return 0
            
        # or "X yard pass"
        elif w in ("yd","yds","yrd","yrds","yard","yards") and len(words) >= j+2:
            if words[j+1].rstrip(".,") in ("pass"):
                return int(words[j-1])

    # Or maybe pass went incomplete
    if "incomplete" in detail.lower():
        return 0
    
    # Or maybe pass was intercepted. In this case, just say yds_gained is zero
    elif ("intercepted" in detail.lower()) or ("interception" in detail.lower()):
        return 0
    
    return "x"

def parse_details(df):
    df = df[['down','detail']]
    
    # Make a bunch of dictionaries for storing play-specific data
    is_parseable = {}
    is_run = {}
    is_scramble = {}
    is_pass = {}
    is_punt = {}
    is_fieldgoal = {}
    runpass_play = {}
    yds_gained = {}
    
    # Loop through details going through logic tree
    for (pid, d) in zip(df.index, df.detail.values): 
        
        # Look exclusively for play details on downs 1-4
        if df.loc[pid,'down'] in [1,2,3,4]:
            
            # Parse a scramble
            if found_scramble(d):
                is_scramble[pid] = True
                yds_gained[pid] = yds_run(d)
                
            if found_run(d):
                is_run[pid] = True
                yds_gained[pid] = yds_run(d)
                
            if found_pass(d):
                is_pass[pid] = True
                yds_gained[pid] = yds_passed(d)
                
            elif found_punt(d):
                is_punt[pid] = True
                is_parseable[pid] = True
                
            elif found_fieldgoal(d):
                is_fieldgoal[pid] = True
                is_parseable[pid] = True
                
            # Check whether play was totally "parseable"
            if (
                ((pid in is_run) | (pid in is_pass) | (pid in is_scramble)) 
                &
                (pid in yds_gained)
            ):
                runpass_play[pid] = True
                is_parseable[pid] = True

    return [is_parseable, is_run, is_scramble, is_pass,
            is_punt, is_fieldgoal, runpass_play, yds_gained]

# %%
# Structure for getting parsed DF with additional columns
(down, dist, fieldpos) = parse_downdist(rawplays_df)
(qtr, time_rem) = parse_time_rem(rawplays_df)
parsed_df = rawplays_df.loc[:,:]
parsed_df['down'] = down
parsed_df['dist'] = dist
parsed_df['home_fieldpos'] = fieldpos
parsed_df['qtr'] = qtr
parsed_df['time_rem'] = time_rem
parsed_df['secs_rem'] = get_secs_rem(parsed_df)

detail_tuple = parse_details(parsed_df)
parsed_df['is_parseable'] = pd.Series(detail_tuple[0])
parsed_df['is_run'] = pd.Series(detail_tuple[1])
parsed_df['is_scramble'] = pd.Series(detail_tuple[2])
parsed_df['is_pass'] = pd.Series(detail_tuple[3])
parsed_df['is_punt'] = pd.Series(detail_tuple[4])
parsed_df['is_fieldgoal'] = pd.Series(detail_tuple[5])
parsed_df['runpass_play'] = pd.Series(detail_tuple[6])
parsed_df['yds_gained'] = pd.Series(detail_tuple[7])
# Out:
#  R. Tannehill sacked at MIA 1 for -8 yards (C. Avril).

# %%
tf_cols = ['is_parseable','is_run','is_pass','is_scramble',
           'is_punt','is_fieldgoal','runpass_play']
values = {col: False for col in tf_cols}
parsed_df[tf_cols] = parsed_df[tf_cols].fillna("False")
parsed_df['yds_gained'] = parsed_df['yds_gained'].fillna(0)
parsed_df[cols].sample(15)
# Out:
#                                                           detail yds_gained  \
# 400554281-76   (1:45 - 2nd)  (Shotgun) M.Stafford pass short ...          9
# 400554302-83   (0:41 - 2nd)  (Shotgun) D.Carr pass short righ...          9
# 321105018-40   (12:51 - 2nd) M.Vick pass short middle to L.Mc...          0
# 400791550-24   (2:40 - 1st)  (Shotgun) N.Foles pass short lef...         17
# 311002021-94   (11:53 - 3rd) D.Akers 45 yard field goal is BL...          0
# 311226018-61   (5:15 - 2nd)  D.Brees pass short middle intend...          0
# 400874612-33   (2:32 - 1st)  (Shotgun) PENALTY on NYJ-R.Clady...          0
# 311009029-41                                       End of Period          0
# 331124015-108  (8:02 - 3rd)  R.Tannehill pass short right to ...          2
# 400951660-155  (2:31 - 4th)  (No Huddle, Shotgun) M.Stafford ...         18
# 400874576-53   (8:31 - 2nd)  A.Thielen left end pushed ob at ...         11
# 331222012-89   (0:06 - 2nd) R.Succop 47 yard field goal is No...          0
# 321004014-156  (3:26 - 4th) J.Hekker punts 55 yards to ARZ 36...          0
# 400554315-69   (6:15 - 2nd)  (No Huddle, Shotgun) N.Foles pas...          8
# 400874675-58   (7:01 - 2nd)  (Shotgun) A.Smith pass short rig...         -1
#
#               is_parseable is_run is_pass
# 400554281-76          True  False    True
# 400554302-83          True  False    True
# 321105018-40          True  False    True
# 400791550-24          True  False    True
# 311002021-94          True  False   False
# 311226018-61          True  False    True
# 400874612-33         False  False   False
# 311009029-41         False  False   False
# 331124015-108         True  False    True
# 400951660-155         True  False    True
# 400874576-53          True   True   False
# 331222012-89          True  False   False
# 321004014-156         True  False   False
# 400554315-69          True  False    True
# 400874675-58          True  False    True
